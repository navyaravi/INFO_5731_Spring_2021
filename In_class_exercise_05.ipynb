# %% [markdown]
# <a href="https://colab.research.google.com/github/navyaravi/INFO_5731_Spring_2021/blob/main/In_class_exercise_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The fifth In-class-exercise (2/23/2021, 20 points in total)

# %% [markdown]
# In exercise-03, I asked you to collected 500 textual data based on your own information needs (If you didn't collect the textual data, you should recollect for this exercise). Now we need to think about how to represent the textual data for text classification. In this exercise, you are required to select 10 types of features (10 types of features but absolutely more than 10 features) in the followings feature list, then represent the 500 texts with these features. The output should be in the following format:
# ![image.png](attachment:image.png)
#
# The feature list:
#
# * (1) tf-idf features
# * (2) POS-tag features: number of adjective, adverb, auxiliary, punctuation, complementizer, coordinating conjunction, subordinating conjunction, determiner, interjection, noun, possessor, preposition, pronoun, quantifier, verb, and other. (select some of them if you use pos-tag features)
# * (3) Linguistic features:
#   * number of right-branching nodes across all constituent types
#   * number of right-branching nodes for NPs only
#   * number of left-branching nodes across all constituent types
#   * number of left-branching nodes for NPs only
#   * number of premodifiers across all constituent types
#   * number of premodifiers within NPs only
#   * number of postmodifiers across all constituent types
#   * number of postmodifiers within NPs only
#   * branching index across all constituent types, i.e. the number of right-branching nodes minus number of left-branching nodes
#   * branching index for NPs only
#   * branching weight index: number of tokens covered by right-branching nodes minus number of tokens covered by left-branching nodes across all categories
#   * branching weight index for NPs only
#   * modification index, i.e. the number of premodifiers minus the number of postmodifiers across all categories
#   * modification index for NPs only
#   * modification weight index: length in tokens of all premodifiers minus length in tokens of all postmodifiers across all categories
#   * modification weight index for NPs only
#   * coordination balance, i.e. the maximal length difference in coordinated constituents
#
#   * density (density can be calculated using the ratio of folowing function words to content words) of determiners/quantifiers
#   * density of pronouns
#   * density of prepositions
#   * density of punctuation marks, specifically commas and semicolons
#   * density of auxiliary verbs
#   * density of conjunctions
#   * density of different pronoun types: Wh, 1st, 2nd, and 3rd person pronouns
#
#   * maximal and average NP length
#   * maximal and average AJP length
#   * maximal and average PP length
#   * maximal and average AVP length
#   * sentence length
#
# * Other features in your mind (ie., pre-defined patterns)

# %%
# Please write your code here

# %% [markdown]
# **Extracting Data**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
main_text = [] # List to store Review headings
sub_text =[] #List to store reviews
for number in range(52):
  link = "https://www.flipkart.com/realme-7-mist-white-64-gb/product-reviews/itme55d08631f19b?pid=MOBFUYUNDSH7NMVT&lid=LSTMOBFUYUNDSH7NMVTWLABPJ&marketplace=FLIPKART&page=" + str(number) # Generating link dynamically
  page = requests.get(link) # Accessing the webpage
  soup = BeautifulSoup(page.text, 'html.parser')
  main_reviews = soup.find_all(class_='_2-N8zT') # Getting the Review Heading by using the class name
  text_reviews = soup.find_all(class_='t-ZTKy') # Getting the full reviews by using the class name
  for ele, sub_ele in zip(main_reviews, text_reviews) : # Iterating through the list
      main_text.append(ele.text) #Appending to empty list
      sub_text.append(sub_ele.text)
df = pd.DataFrame(list(zip(main_text, sub_text)), columns =['Glimpse of Review', 'Full Review'])  # Creating Dataframe
print("Length of data frame is {0}".format(len(df)))
df
# Out:
# Length of data frame is 510
#          Glimpse of Review                                        Full Review
# 0     Good quality product  Good value for money and a phone with good cam...
# 1                Must buy!  best camera and display and best performance i...
# 2          Worth the money  Writting this after using for 1 month.Pros.1. ...
# 3                Wonderful  When we talk about a brand loyal person....so ...
# 4    Mind-blowing purchase  Best phone in the range Camera is better ✔️Bat...
# ..                     ...                                                ...
# 505              Excellent                                      GoodREAD MORE
# 506         Classy product                                   awesomeREAD MORE
# 507              Must buy!                                     HappyREAD MORE
# 508              Just wow!                                Nice phoneREAD MORE
# 509      Terrific purchase                           Happy to buy itREAD MORE
#
# [510 rows x 2 columns]

# %% [markdown]
# **Preprocessing Data**

# %% [markdown]
# **Converting to lower case**

# %%
df['After Preprocessing'] = df['Full Review'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df
# Out:
#          Glimpse of Review  ...                                After Preprocessing
# 0     Good quality product  ...  good value for money and a phone with good cam...
# 1                Must buy!  ...  best camera and display and best performance i...
# 2          Worth the money  ...  writting this after using for 1 month.pros.1. ...
# 3                Wonderful  ...  when we talk about a brand loyal person....so ...
# 4    Mind-blowing purchase  ...  best phone in the range camera is better ✔️bat...
# ..                     ...  ...                                                ...
# 505              Excellent  ...                                      goodread more
# 506         Classy product  ...                                   awesomeread more
# 507              Must buy!  ...                                     happyread more
# 508              Just wow!  ...                                nice phoneread more
# 509      Terrific purchase  ...                           happy to buy itread more
#
# [510 rows x 3 columns]

# %% [markdown]
# **Removing Punctuation**

# %%
df['After Preprocessing'] = df['After Preprocessing'].str.replace('[^\w\s]','')
df
# Out:
#          Glimpse of Review  ...                                After Preprocessing
# 0     Good quality product  ...  good value for money and a phone with good cam...
# 1                Must buy!  ...  best camera and display and best performance i...
# 2          Worth the money  ...  writting this after using for 1 monthpros1 cam...
# 3                Wonderful  ...  when we talk about a brand loyal personso here...
# 4    Mind-blowing purchase  ...  best phone in the range camera is better batte...
# ..                     ...  ...                                                ...
# 505              Excellent  ...                                      goodread more
# 506         Classy product  ...                                   awesomeread more
# 507              Must buy!  ...                                     happyread more
# 508              Just wow!  ...                                nice phoneread more
# 509      Terrific purchase  ...                           happy to buy itread more
#
# [510 rows x 3 columns]

# %% [markdown]
# **Removing Numerics**

# %%
df['After Preprocessing'] = df['After Preprocessing'].apply(lambda x: ''.join([i for i in x if not i.isdigit()]))

# %% [markdown]
# **Removing Special Characters**

# %%
import re
df['After Preprocessing'] = df['After Preprocessing'].apply(lambda x: ''.join(re.sub(r"[^a-zA-Z0-9]+", ' ', charctr) for charctr in x ))
df
# Out:
#          Glimpse of Review  ...                                After Preprocessing
# 0     Good quality product  ...  good value for money and a phone with good cam...
# 1                Must buy!  ...  best camera and display and best performance i...
# 2          Worth the money  ...  writting this after using for  monthpros camer...
# 3                Wonderful  ...  when we talk about a brand loyal personso here...
# 4    Mind-blowing purchase  ...  best phone in the range camera is better batte...
# ..                     ...  ...                                                ...
# 505              Excellent  ...                                      goodread more
# 506         Classy product  ...                                   awesomeread more
# 507              Must buy!  ...                                     happyread more
# 508              Just wow!  ...                                nice phoneread more
# 509      Terrific purchase  ...                           happy to buy itread more
#
# [510 rows x 3 columns]

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
#     Downloading collection 'all'
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Unzipping corpora/cess_cat.zip.
#        | Downloading package cess_esp to /root/nltk_data...
#        |   Unzipping corpora/cess_esp.zip.
#        | Downloading package chat80 to /root/nltk_data...
#        |   Unzipping corpora/chat80.zip.
#        | Downloading package city_database to /root/nltk_data...
#        |   Unzipping corpora/city_database.zip.
#        | Downloading package cmudict to /root/nltk_data...
#        |   Unzipping corpora/cmudict.zip.
#        | Downloading package comparative_sentences to
#        |     /root/nltk_data...
#        |   Unzipping corpora/comparative_sentences.zip.
#        | Downloading package comtrans to /root/nltk_data...
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Unzipping corpora/conll2000.zip.
#        | Downloading package conll2002 to /root/nltk_data...
#        |   Unzipping corpora/conll2002.zip.
#        | Downloading package conll2007 to /root/nltk_data...
#        | Downloading package crubadan to /root/nltk_data...
#        |   Unzipping corpora/crubadan.zip.
#        | Downloading package dependency_treebank to /root/nltk_data...
#        |   Unzipping corpora/dependency_treebank.zip.
#        | Downloading package dolch to /root/nltk_data...
#        |   Unzipping corpora/dolch.zip.
#        | Downloading package europarl_raw to /root/nltk_data...
#        |   Unzipping corpora/europarl_raw.zip.
#        | Downloading package floresta to /root/nltk_data...
#        |   Unzipping corpora/floresta.zip.
#        | Downloading package framenet_v15 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v15.zip.
#        | Downloading package framenet_v17 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v17.zip.
#        | Downloading package gazetteers to /root/nltk_data...
#        |   Unzipping corpora/gazetteers.zip.
#        | Downloading package genesis to /root/nltk_data...
#        |   Unzipping corpora/genesis.zip.
#        | Downloading package gutenberg to /root/nltk_data...
#        |   Unzipping corpora/gutenberg.zip.
#        | Downloading package ieer to /root/nltk_data...
#        |   Unzipping corpora/ieer.zip.
#        | Downloading package inaugural to /root/nltk_data...
#        |   Unzipping corpora/inaugural.zip.
#        | Downloading package indian to /root/nltk_data...
#        |   Unzipping corpora/indian.zip.
#        | Downloading package jeita to /root/nltk_data...
#        | Downloading package kimmo to /root/nltk_data...
#        |   Unzipping corpora/kimmo.zip.
#        | Downloading package knbc to /root/nltk_data...
#        | Downloading package lin_thesaurus to /root/nltk_data...
#        |   Unzipping corpora/lin_thesaurus.zip.
#        | Downloading package mac_morpho to /root/nltk_data...
#        |   Unzipping corpora/mac_morpho.zip.
#        | Downloading package machado to /root/nltk_data...
#        | Downloading package masc_tagged to /root/nltk_data...
#        | Downloading package moses_sample to /root/nltk_data...
#        |   Unzipping models/moses_sample.zip.
#        | Downloading package movie_reviews to /root/nltk_data...
#        |   Unzipping corpora/movie_reviews.zip.
#        | Downloading package names to /root/nltk_data...
#        |   Unzipping corpora/names.zip.
#        | Downloading package nombank.1.0 to /root/nltk_data...
#        | Downloading package nps_chat to /root/nltk_data...
#        |   Unzipping corpora/nps_chat.zip.
#        | Downloading package omw to /root/nltk_data...
#        |   Unzipping corpora/omw.zip.
#        | Downloading package opinion_lexicon to /root/nltk_data...
#        |   Unzipping corpora/opinion_lexicon.zip.
#        | Downloading package paradigms to /root/nltk_data...
#        |   Unzipping corpora/paradigms.zip.
#        | Downloading package pil to /root/nltk_data...
#        |   Unzipping corpora/pil.zip.
#        | Downloading package pl196x to /root/nltk_data...
#        |   Unzipping corpora/pl196x.zip.
#        | Downloading package ppattach to /root/nltk_data...
#        |   Unzipping corpora/ppattach.zip.
#        | Downloading package problem_reports to /root/nltk_data...
#        |   Unzipping corpora/problem_reports.zip.
#        | Downloading package propbank to /root/nltk_data...
#        | Downloading package ptb to /root/nltk_data...
#        |   Unzipping corpora/ptb.zip.
#        | Downloading package product_reviews_1 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_1.zip.
#        | Downloading package product_reviews_2 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_2.zip.
#        | Downloading package pros_cons to /root/nltk_data...
#        |   Unzipping corpora/pros_cons.zip.
#        | Downloading package qc to /root/nltk_data...
#        |   Unzipping corpora/qc.zip.
#        | Downloading package reuters to /root/nltk_data...
#        | Downloading package rte to /root/nltk_data...
#        |   Unzipping corpora/rte.zip.
#        | Downloading package semcor to /root/nltk_data...
#        | Downloading package senseval to /root/nltk_data...
#        |   Unzipping corpora/senseval.zip.
#        | Downloading package sentiwordnet to /root/nltk_data...
#        |   Unzipping corpora/sentiwordnet.zip.
#        | Downloading package sentence_polarity to /root/nltk_data...
#        |   Unzipping corpora/sentence_polarity.zip.
#        | Downloading package shakespeare to /root/nltk_data...
#        |   Unzipping corpora/shakespeare.zip.
#        | Downloading package sinica_treebank to /root/nltk_data...
#        |   Unzipping corpora/sinica_treebank.zip.
#        | Downloading package smultron to /root/nltk_data...
#        |   Unzipping corpora/smultron.zip.
#        | Downloading package state_union to /root/nltk_data...
#        |   Unzipping corpora/state_union.zip.
#        | Downloading package stopwords to /root/nltk_data...
#        |   Unzipping corpora/stopwords.zip.
#        | Downloading package subjectivity to /root/nltk_data...
#        |   Unzipping corpora/subjectivity.zip.
#        | Downloading package swadesh to /root/nltk_data...
#        |   Unzipping corpora/swadesh.zip.
#        | Downloading package switchboard to /root/nltk_data...
#        |   Unzipping corpora/switchboard.zip.
#        | Downloading package timit to /root/nltk_data...
#        |   Unzipping corpora/timit.zip.
#        | Downloading package toolbox to /root/nltk_data...
#        |   Unzipping corpora/toolbox.zip.
#        | Downloading package treebank to /root/nltk_data...
#        |   Unzipping corpora/treebank.zip.
#        | Downloading package twitter_samples to /root/nltk_data...
#        |   Unzipping corpora/twitter_samples.zip.
#        | Downloading package udhr to /root/nltk_data...
#        |   Unzipping corpora/udhr.zip.
#        | Downloading package udhr2 to /root/nltk_data...
#        |   Unzipping corpora/udhr2.zip.
#        | Downloading package unicode_samples to /root/nltk_data...
#        |   Unzipping corpora/unicode_samples.zip.
#        | Downloading package universal_treebanks_v20 to
#        |     /root/nltk_data...
#        | Downloading package verbnet to /root/nltk_data...
#        |   Unzipping corpora/verbnet.zip.
#        | Downloading package verbnet3 to /root/nltk_data...
#        |   Unzipping corpora/verbnet3.zip.
#        | Downloading package webtext to /root/nltk_data...
#        |   Unzipping corpora/webtext.zip.
#        | Downloading package wordnet to /root/nltk_data...
#        |   Unzipping corpora/wordnet.zip.
#        | Downloading package wordnet_ic to /root/nltk_data...
#        |   Unzipping corpora/wordnet_ic.zip.
#        | Downloading package words to /root/nltk_data...
#        |   Unzipping corpora/words.zip.
#        | Downloading package ycoe to /root/nltk_data...
#        |   Unzipping corpora/ycoe.zip.
#        | Downloading package rslp to /root/nltk_data...
#        |   Unzipping stemmers/rslp.zip.
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
#        | Downloading package universal_tagset to /root/nltk_data...
#        |   Unzipping taggers/universal_tagset.zip.
#        | Downloading package maxent_ne_chunker to /root/nltk_data...
#        |   Unzipping chunkers/maxent_ne_chunker.zip.
#        | Downloading package punkt to /root/nltk_data...
#        |   Unzipping tokenizers/punkt.zip.
#        | Downloading package book_grammars to /root/nltk_data...
#        |   Unzipping grammars/book_grammars.zip.
#        | Downloading package sample_grammars to /root/nltk_data...
#        |   Unzipping grammars/sample_grammars.zip.
#        | Downloading package spanish_grammars to /root/nltk_data...
#        |   Unzipping grammars/spanish_grammars.zip.
#        | Downloading package basque_grammars to /root/nltk_data...
#        |   Unzipping grammars/basque_grammars.zip.
#        | Downloading package large_grammars to /root/nltk_data...
#        |   Unzipping grammars/large_grammars.zip.
#        | Downloading package tagsets to /root/nltk_data...
#        |   Unzipping help/tagsets.zip.
#        | Downloading package snowball_data to /root/nltk_data...
#        | Downloading package bllip_wsj_no_aux to /root/nltk_data...
#        |   Unzipping models/bllip_wsj_no_aux.zip.
#        | Downloading package word2vec_sample to /root/nltk_data...
#        |   Unzipping models/word2vec_sample.zip.
#        | Downloading package panlex_swadesh to /root/nltk_data...
#        | Downloading package mte_teip5 to /root/nltk_data...
#        |   Unzipping corpora/mte_teip5.zip.
#        | Downloading package averaged_perceptron_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger.zip.
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger_ru.zip.
#        | Downloading package perluniprops to /root/nltk_data...
#        |   Unzipping misc/perluniprops.zip.
#        | Downloading package nonbreaking_prefixes to
#        |     /root/nltk_data...
#        |   Unzipping corpora/nonbreaking_prefixes.zip.
#        | Downloading package vader_lexicon to /root/nltk_data...
#        | Downloading package porter_test to /root/nltk_data...
#        |   Unzipping stemmers/porter_test.zip.
#        | Downloading package wmt15_eval to /root/nltk_data...
#        |   Unzipping models/wmt15_eval.zip.
#        | Downloading package mwa_ppdb to /root/nltk_data...
#        |   Unzipping misc/mwa_ppdb.zip.
#        |
#      Done downloading collection all
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %% [markdown]
# **Removing Stop Words**

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
df['After Preprocessing'] = df['After Preprocessing'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df
# Out:
#          Glimpse of Review  ...                                After Preprocessing
# 0     Good quality product  ...  good value money phone good camera great batte...
# 1                Must buy!  ...  best camera display best performance segment e...
# 2          Worth the money  ...  writting using monthpros camera good price ran...
# 3                Wonderful  ...  talk brand loyal personso amit pleasure say th...
# 4    Mind-blowing purchase  ...  best phone range camera better battery backup ...
# ..                     ...  ...                                                ...
# 505              Excellent  ...                                           goodread
# 506         Classy product  ...                                        awesomeread
# 507              Must buy!  ...                                          happyread
# 508              Just wow!  ...                                     nice phoneread
# 509      Terrific purchase  ...                                   happy buy itread
#
# [510 rows x 3 columns]

# %% [markdown]
# **Spelling Correction**

# %%
from textblob import TextBlob
df['After Preprocessing'].apply(lambda x: str(TextBlob(x).correct()))
# Out:
# 0      good value money phone good camera great batte...
# 1      best camera display best performance segment e...
# 2      writing using monthpros camera good price rang...
# 3      talk brand loyal persons amid pleasure say tha...
# 4      best phone range camera better battery back ok...
#                              ...
# 505                                             goodread
# 506                                          awesomeread
# 507                                            happyread
# 508                                       nice phoneread
# 509                                      happy buy tread
# Name: After Preprocessing, Length: 510, dtype: object

# %% [markdown]
# **Stemming**

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
df['After Preprocessing'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
# Out:
# 0      good valu money phone good camera great batter...
# 1      best camera display best perform segment excel...
# 2      writ use monthpro camera good price rang compa...
# 3      talk brand loyal personso amit pleasur say tha...
# 4      best phone rang camera better batteri backup o...
#                              ...
# 505                                             goodread
# 506                                          awesomeread
# 507                                            happyread
# 508                                       nice phoneread
# 509                                     happi buy itread
# Name: After Preprocessing, Length: 510, dtype: object

# %% [markdown]
# **Lemmatization**

# %%
from textblob import Word
import nltk
nltk.download('wordnet')

df['After Preprocessing'] = df['After Preprocessing'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#          Glimpse of Review  ...                                After Preprocessing
# 0     Good quality product  ...  good value money phone good camera great batte...
# 1                Must buy!  ...  best camera display best performance segment e...
# 2          Worth the money  ...  writting using monthpros camera good price ran...
# 3                Wonderful  ...  talk brand loyal personso amit pleasure say th...
# 4    Mind-blowing purchase  ...  best phone range camera better battery backup ...
# ..                     ...  ...                                                ...
# 505              Excellent  ...                                           goodread
# 506         Classy product  ...                                        awesomeread
# 507              Must buy!  ...                                          happyread
# 508              Just wow!  ...                                     nice phoneread
# 509      Terrific purchase  ...                                   happy buy itread
#
# [510 rows x 3 columns]

# %% [markdown]
# **Parts of Speech Tagging and Features**

# %%
from nltk.tokenize import word_tokenize
pos = []
for sentence in df['After Preprocessing']:
  text = word_tokenize(sentence)
  pos.append(nltk.pos_tag(text))
pos
# Out:
# [[('good', 'JJ'),
#   ('value', 'NN'),
#   ('money', 'NN'),
#   ('phone', 'NN'),
#   ('good', 'JJ'),
#   ('camera', 'NN'),
#   ('great', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('fast', 'VBD'),
#   ('charging', 'VBG'),
#   ('life', 'NN'),
#   ('saver', 'NN'),
#   ('sometimesread', 'NN')],
#  [('best', 'JJS'),
#   ('camera', 'NN'),
#   ('display', 'NN'),
#   ('best', 'JJS'),
#   ('performance', 'NN'),
#   ('segment', 'NN'),
#   ('excellent', 'JJ'),
#   ('gaming', 'VBG'),
#   ('pubg', 'NN'),
#   ('experiece', 'NN'),
#   ('perfect', 'JJ'),
#   ('g', 'NN'),
#   ('processor', 'NN'),
#   ('give', 'VBP'),
#   ('best', 'JJS'),
#   ('performanceread', 'NN')],
#  [('writting', 'VBG'),
#   ('using', 'VBG'),
#   ('monthpros', 'NNS'),
#   ('camera', 'RB'),
#   ('good', 'JJ'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('compact', 'JJ'),
#   ('design', 'NN'),
#   ('easily', 'RB'),
#   ('usable', 'JJ'),
#   ('one', 'CD'),
#   ('hand', 'NN'),
#   ('heavy', 'JJ'),
#   ('bloatware', 'NN'),
#   ('installed', 'VBN'),
#   ('realme', 'NN'),
#   ('apps', 'NN'),
#   ('battery', 'NN'),
#   ('durability', 'NN'),
#   ('quite', 'RB'),
#   ('good', 'JJ'),
#   ('heating', 'NN'),
#   ('issue', 'NN'),
#   ('found', 'VBD'),
#   ('even', 'RB'),
#   ('playing', 'VBG'),
#   ('pubg', 'JJ'),
#   ('hourscons', 'NNS'),
#   ('sometimes', 'RB'),
#   ('photo', 'VBP'),
#   ('exposed', 'VBN'),
#   ('camera', 'NN'),
#   ('software', 'NN'),
#   ('optimization', 'NN'),
#   ('need', 'VBP'),
#   ('improved', 'VBN'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('disappointing', 'JJ'),
#   ('display', 'NN'),
#   ('brightness', 'NN'),
#   ('enough', 'JJ'),
#   ('sunny', 'JJ'),
#   ('day', 'NN'),
#   ('youll', 'VB'),
#   ('get', 'NN'),
#   ('troubleread', 'NN')],
#  [('talk', 'NN'),
#   ('brand', 'NN'),
#   ('loyal', 'NN'),
#   ('personso', 'NN'),
#   ('amit', 'NN'),
#   ('pleasure', 'NN'),
#   ('say', 'VBP'),
#   ('thatyou', 'NN'),
#   ('coming', 'VBG'),
#   ('superb', 'JJ'),
#   ('brand', 'NN'),
#   ('already', 'RB'),
#   ('known', 'VBN'),
#   ('realmethis', 'NN'),
#   ('realme', 'NN'),
#   ('mist', 'NN'),
#   ('blue', 'IN'),
#   ('colour', 'NN'),
#   ('awesome', 'RB'),
#   ('well', 'RB'),
#   ('performance', 'NN'),
#   ('unbeatablei', 'JJ'),
#   ('mean', 'JJ'),
#   ('wow', 'NN'),
#   ('yrthis', 'NN'),
#   ('handset', 'NN'),
#   ('different', 'JJ'),
#   ('personality', 'NN'),
#   ('carried', 'VBD'),
#   ('whether', 'IN'),
#   ('inside', 'IN'),
#   ('house', 'NN'),
#   ('outside', 'IN'),
#   ('party', 'NN'),
#   ('wedding', 'NN'),
#   ('functionwhat', 'WP'),
#   ('wonderful', 'JJ'),
#   ('performance', 'NN'),
#   ('broso', 'NN'),
#   ('prerer', 'NN'),
#   ('purchase', 'NN'),
#   ('phoneand', 'NN'),
#   ('iread', 'NN')],
#  [('best', 'JJS'),
#   ('phone', 'NN'),
#   ('range', 'NN'),
#   ('camera', 'NN'),
#   ('better', 'RBR'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('ok', 'IN'),
#   ('fast', 'JJ'),
#   ('charging', 'VBG'),
#   ('look', 'NN'),
#   ('mustperfomence', 'NN'),
#   ('good', 'JJ'),
#   ('aal', 'NN'),
#   ('goodread', 'NN')],
#  [('realme', 'NN'),
#   ('branded', 'VBD'),
#   ('mobile', 'JJ'),
#   ('value', 'NN'),
#   ('money', 'NN'),
#   ('good', 'JJ'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('display', 'NN'),
#   ('awesomesound', 'IN'),
#   ('quality', 'NN'),
#   ('nice', 'RB'),
#   ('good', 'JJ'),
#   ('gaming', 'NN'),
#   ('camera', 'NN'),
#   ('extremely', 'RB'),
#   ('super', 'JJ'),
#   ('good', 'JJ'),
#   ('quality', 'NN'),
#   ('pic', 'NNS'),
#   ('side', 'VBP'),
#   ('fingerprint', 'NN'),
#   ('sensor', 'NN'),
#   ('nyc', 'JJ'),
#   ('speed', 'NN'),
#   ('front', 'NN'),
#   ('camera', 'NN'),
#   ('super', 'JJ'),
#   ('worth', 'NN'),
#   ('maney', 'NN'),
#   ('lag', 'NN'),
#   ('struck', 'VBD'),
#   ('watt', 'JJ'),
#   ('charger', 'NN'),
#   ('superread', 'NN')],
#  [('price', 'NN'),
#   ('phone', 'NN'),
#   ('awesome', 'JJ'),
#   ('better', 'RBR'),
#   ('camera', 'NN'),
#   ('performance', 'NN'),
#   ('k', 'NN'),
#   ('video', 'NN'),
#   ('recording', 'VBG'),
#   ('mp', 'NN'),
#   ('photo', 'NN'),
#   ('also', 'RB'),
#   ('available', 'JJ'),
#   ('raw', 'JJ'),
#   ('mode', 'NN'),
#   ('phone', 'NN'),
#   ('heating', 'NN'),
#   ('disappointed', 'JJ'),
#   ('ai', 'NN'),
#   ('change', 'NN'),
#   ('refresh', 'JJ'),
#   ('refresh', 'NN'),
#   ('rate', 'NN'),
#   ('work', 'NN'),
#   ('properly', 'RB'),
#   ('thats', 'NNS'),
#   ('always', 'RB'),
#   ('refresh', 'VBP'),
#   ('rate', 'NN'),
#   ('provide', 'VBP'),
#   ('much', 'JJ'),
#   ('faster', 'JJR'),
#   ('work', 'NN'),
#   ('touch', 'NN'),
#   ('still', 'RB'),
#   ('heatedread', 'VB')],
#  [('good', 'JJ'),
#   ('asome', 'NN'),
#   ('mobile', 'JJ'),
#   ('battery', 'NN'),
#   ('good', 'JJ'),
#   ('fast', 'RB'),
#   ('charge', 'NN'),
#   ('love', 'VB'),
#   ('phone', 'NN'),
#   ('camera', 'NN'),
#   ('niceread', 'NN')],
#  [('phone', 'NN'),
#   ('good', 'JJ'),
#   ('price', 'NN'),
#   ('work', 'NN'),
#   ('well', 'RB'),
#   ('problemperformance', 'RB'),
#   ('good', 'JJ'),
#   ('little', 'JJ'),
#   ('heating', 'NN'),
#   ('problem', 'NN'),
#   ('heavy', 'JJ'),
#   ('gaming', 'NN'),
#   ('multitaskingbattery', 'JJ'),
#   ('life', 'NN'),
#   ('awesome', 'JJ'),
#   ('charging', 'VBG'),
#   ('fastbuild', 'JJ'),
#   ('quality', 'NN'),
#   ('fine', 'JJ'),
#   ('little', 'JJ'),
#   ('bit', 'NN'),
#   ('thick', 'JJ'),
#   ('heavycamera', 'NN'),
#   ('fine', 'NN'),
#   ('main', 'JJ'),
#   ('lens', 'NNS'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('ultra', 'JJ'),
#   ('wide', 'JJ'),
#   ('angle', 'NN'),
#   ('lens', 'VBZ'),
#   ('great', 'JJ'),
#   ('remaining', 'VBG'),
#   ('lens', 'JJ'),
#   ('uselessno', 'JJ'),
#   ('noise', 'NN'),
#   ('cancellation', 'NN'),
#   ('mic', 'FW'),
#   ('call', 'NN'),
#   ('recordingdisplay', 'NN'),
#   ('also', 'RB'),
#   ('goodtotally', 'RB'),
#   ('phone', 'NN'),
#   ('good', 'JJ'),
#   ('problem', 'NN'),
#   ('face', 'NN'),
#   ('phone', 'NN'),
#   ('isread', 'NN')],
#  [('image', 'NN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('nice', 'JJ'),
#   ('look', 'NN'),
#   ('good', 'JJ'),
#   ('performance', 'NN'),
#   ('battery', 'NN'),
#   ('good', 'JJ'),
#   ('like', 'IN'),
#   ('battery', 'NN'),
#   ('backupread', 'NN')],
#  [('best', 'RB'),
#   ('mobile', 'RB'),
#   ('good', 'JJ'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('fast', 'RB'),
#   ('refresh', 'JJ'),
#   ('rate', 'NN'),
#   ('value', 'NN'),
#   ('money', 'NN'),
#   ('must', 'MD'),
#   ('enjoyed', 'VBN'),
#   ('mobileread', 'NN')],
#  [('good', 'JJ'),
#   ('product', 'NN'),
#   ('good', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('excellent', 'JJ'),
#   ('processor', 'NN'),
#   ('smooth', 'JJ'),
#   ('display', 'NN'),
#   ('good', 'JJ'),
#   ('designread', 'NN')],
#  [('phone', 'NN'),
#   ('overall', 'JJ'),
#   ('performance', 'NN'),
#   ('good', 'NN'),
#   ('purchased', 'VBD'),
#   ('gb', 'JJ'),
#   ('ram', 'NN'),
#   ('gb', 'NN'),
#   ('rom', 'NN'),
#   ('handsetits', 'NNS'),
#   ('gon', 'VBP'),
#   ('na', 'TO'),
#   ('hang', 'VB'),
#   ('incoming', 'VBG'),
#   ('callsmy', 'JJ'),
#   ('old', 'JJ'),
#   ('f', 'NN'),
#   ('faar', 'NN'),
#   ('better', 'RBR'),
#   ('working', 'VBG'),
#   ('phonei', 'NN'),
#   ('personally', 'RB'),
#   ('suggest', 'VBP'),
#   ('dont', 'JJ'),
#   ('buy', 'NN'),
#   ('hanging', 'VBG'),
#   ('phoneno', 'JJ'),
#   ('value', 'NN'),
#   ('moneybattory', 'NN'),
#   ('pretty', 'RB'),
#   ('good', 'JJ'),
#   ('camera', 'NN'),
#   ('also', 'RB'),
#   ('working', 'VBG'),
#   ('nicebut', 'RB'),
#   ('hanging', 'VBG'),
#   ('problem', 'NN'),
#   ('majorso', 'NN'),
#   ('im', 'NN'),
#   ('going', 'VBG'),
#   ('recommend', 'VB'),
#   ('phone', 'NN'),
#   ('youread', 'NN')],
#  [('overall', 'JJ'),
#   ('like', 'IN'),
#   ('phone', 'NN'),
#   ('good', 'JJ'),
#   ('performance', 'NN'),
#   ('camera', 'NN'),
#   ('battery', 'NN'),
#   ('also', 'RB'),
#   ('better', 'RB'),
#   ('high', 'JJ'),
#   ('still', 'RB'),
#   ('satisfied', 'VBN'),
#   ('phoneread', 'NN')],
#  [('good', 'JJ'),
#   ('best', 'JJS'),
#   ('quality', 'NN'),
#   ('cameraselfie', 'NN'),
#   ('good', 'JJ'),
#   ('main', 'JJ'),
#   ('camera', 'NN'),
#   ('awesomeoverall', 'NN'),
#   ('phone', 'NN'),
#   ('fabulous', 'JJ'),
#   ('read', 'NN')],
#  [('awesome', 'JJ'),
#   ('mobile', 'JJ'),
#   ('camera', 'NN'),
#   ('good', 'JJ'),
#   ('front', 'NN'),
#   ('camera', 'NN'),
#   ('much', 'JJ'),
#   ('better', 'JJR'),
#   ('overall', 'JJ'),
#   ('better', 'RBR'),
#   ('samsung', 'NN'),
#   ('planning', 'VBG'),
#   ('smartphones', 'NNS'),
#   ('change', 'NN'),
#   ('desigen', 'NN'),
#   ('buy', 'VB'),
#   ('realme', 'JJ'),
#   ('charging', 'VBG'),
#   ('tooo', 'NN'),
#   ('goodread', 'NN')],
#  [('best', 'JJS'),
#   ('phone', 'NN'),
#   ('rangecamera', 'NN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('best', 'RBS'),
#   ('performancebatyery', 'NN'),
#   ('backup', 'NN'),
#   ('high', 'JJ'),
#   ('fast', 'RB'),
#   ('chargingphone', 'NN'),
#   ('excellentread', 'NN')],
#  [('first', 'RB'),
#   ('realme', 'VBZ'),
#   ('phonethe', 'JJ'),
#   ('user', 'JJ'),
#   ('experience', 'NN'),
#   ('nicethe', 'JJ'),
#   ('delivery', 'NN'),
#   ('fast', 'RB'),
#   ('im', 'JJ'),
#   ('ordered', 'VBD'),
#   ('th', 'JJ'),
#   ('sep', 'JJ'),
#   ('receive', 'VBP'),
#   ('septemberthe', 'JJ'),
#   ('performance', 'NN'),
#   ('mobile', 'NN'),
#   ('really', 'RB'),
#   ('nice', 'JJ'),
#   ('look', 'NN'),
#   ('awesome', 'JJ'),
#   ('camera', 'NN'),
#   ('amezingpros', 'NN'),
#   ('hz', 'NN'),
#   ('display', 'NN'),
#   ('refresh', 'JJ'),
#   ('rate', 'NN'),
#   ('battery', 'NN'),
#   ('world', 'NN'),
#   ('first', 'RB'),
#   ('helio', 'JJ'),
#   ('g', 'NN'),
#   ('prosseserread', 'NN')],
#  [('perfect', 'NN'),
#   ('mobile', 'JJ'),
#   ('considering', 'VBG'),
#   ('price', 'NN'),
#   ('bracket', 'NN'),
#   ('software', 'NN'),
#   ('clean', 'JJ'),
#   ('experience', 'NN'),
#   ('changed', 'VBD'),
#   ('software', 'NN'),
#   ('experience', 'NN'),
#   ('good', 'JJ'),
#   ('try', 'NN'),
#   ('note', 'NN'),
#   ('rather', 'RB'),
#   ('read', 'VBD')],
#  [('brillianti', 'NNS'),
#   ('like', 'IN'),
#   ('bodyclass', 'NN'),
#   ('finishram', 'NN'),
#   ('management', 'NN'),
#   ('good', 'JJ'),
#   ('gaming', 'NN'),
#   ('good', 'JJ'),
#   ('absolutely', 'RB'),
#   ('fabulous', 'JJ'),
#   ('read', 'NN')],
#  [('prosrealme', 'RB'),
#   ('fabulous', 'JJ'),
#   ('mp', 'NNS'),
#   ('cam', 'VBP'),
#   ('w', 'JJ'),
#   ('fast', 'RB'),
#   ('charger', 'NN'),
#   ('good', 'JJ'),
#   ('battery', 'NN'),
#   ('lifeconsits', 'NNS'),
#   ('weight', 'VBD'),
#   ('heavy', 'JJ'),
#   ('though', 'IN'),
#   ('mah', 'JJ'),
#   ('battery', 'NN'),
#   ('realme', 'NN'),
#   ('take', 'VB'),
#   ('look', 'NN'),
#   ('onceread', 'NN')],
#  [('love', 'VB'),
#   ('phone', 'NN'),
#   ('everything', 'NN'),
#   ('good', 'JJ'),
#   ('according', 'VBG'),
#   ('price', 'NN'),
#   ('best', 'JJS'),
#   ('phone', 'NN'),
#   ('yet', 'RB'),
#   ('could', 'MD'),
#   ('buy', 'VB'),
#   ('blindlyread', 'JJ')],
#  [('overall', 'JJ'),
#   ('performance', 'NN'),
#   ('osmghost', 'NN'),
#   ('touch', 'JJ'),
#   ('u', 'JJ'),
#   ('seen', 'VBN'),
#   ('timerear', 'JJ'),
#   ('portrait', 'NN'),
#   ('camera', 'NN'),
#   ('mode', 'NN'),
#   ('good', 'JJ'),
#   ('sellfe', 'NN'),
#   ('camera', 'NN'),
#   ('like', 'IN'),
#   ('mp', 'NN'),
#   ('click', 'NN'),
#   ('lov', 'NN'),
#   ('quality', 'NN'),
#   ('pic', 'NN'),
#   ('ot', 'JJ'),
#   ('time', 'NN'),
#   ('problem', 'NN'),
#   ('using', 'VBG'),
#   ('filter', 'NN'),
#   ('mode', 'NN'),
#   ('rear', 'VBP'),
#   ('megapixel', 'NN'),
#   ('stuggle', 'NN'),
#   ('loteven', 'JJ'),
#   ('selfee', 'NN'),
#   ('video', 'NN'),
#   ('beauty', 'NN'),
#   ('mode', 'NN'),
#   ('disappointingread', 'NN')],
#  [('good', 'JJ'),
#   ('display', 'NN'),
#   ('performance', 'NN'),
#   ('finger', 'NN'),
#   ('print', 'NN'),
#   ('sensor', 'NN'),
#   ('working', 'VBG'),
#   ('fast', 'RB'),
#   ('sound', 'JJ'),
#   ('excellent', 'JJ'),
#   ('earphone', 'NN'),
#   ('long', 'JJ'),
#   ('battery', 'NN'),
#   ('back', 'RB'),
#   ('hr', 'JJ'),
#   ('normal', 'JJ'),
#   ('usage', 'JJ'),
#   ('nice', 'JJ'),
#   ('ui', 'RB'),
#   ('good', 'JJ'),
#   ('camera', 'NN'),
#   ('performancepros', 'NN'),
#   ('low', 'JJ'),
#   ('light', 'JJ'),
#   ('image', 'NN'),
#   ('goodread', 'NN')],
#  [('phone', 'NN'),
#   ('good', 'JJ'),
#   ('think', 'NN'),
#   ('realme', 'NN'),
#   ('x', 'NN'),
#   ('launched', 'VBN'),
#   ('still', 'RB'),
#   ('better', 'RBR'),
#   ('amoled', 'JJ'),
#   ('display', 'NN'),
#   ('better', 'RBR'),
#   ('back', 'RB'),
#   ('camera', 'NN'),
#   ('dont', 'NN'),
#   ('know', 'VBP'),
#   ('realme', 'NN'),
#   ('stopped', 'VBD'),
#   ('giving', 'VBG'),
#   ('amoled', 'JJ'),
#   ('display', 'NN'),
#   ('price', 'NN'),
#   ('segmentand', 'NN'),
#   ('trust', 'NN'),
#   ('back', 'RB'),
#   ('camera', 'NN'),
#   ('realme', 'NN'),
#   ('x', 'NNP'),
#   ('use', 'NN'),
#   ('gcam', 'VBD'),
#   ('good', 'JJ'),
#   ('one', 'CD'),
#   ('plus', 'CC'),
#   ('back', 'RB'),
#   ('camerai', 'NN'),
#   ('saying', 'VBG'),
#   ('use', 'NN'),
#   ('gcam', 'NN'),
#   ('whose', 'WP$'),
#   ('version', 'NN'),
#   ('work', 'NN'),
#   ('one', 'CD'),
#   ('plus', 'CC'),
#   ('realme', 'VB'),
#   ('x', 'NNP'),
#   ('unfortunately', 'RB'),
#   ('doesnt', 'JJ'),
#   ('work', 'NN'),
#   ('realme', 'NN'),
#   ('according', 'VBG'),
#   ('realme', 'JJ'),
#   ('x', 'NN'),
#   ('mindblowing', 'VBG'),
#   ('phone', 'NN'),
#   ('price', 'NN'),
#   ('raread', 'NN')],
#  [('fast', 'RB'),
#   ('delivery', 'NN'),
#   ('two', 'CD'),
#   ('daysexcellent', 'NN'),
#   ('camera', 'NN'),
#   ('hz', 'NN'),
#   ('refresh', 'JJ'),
#   ('rate', 'NN'),
#   ('love', 'IN'),
#   ('itsmother', 'NN'),
#   ('use', 'NN'),
#   ('best', 'JJS'),
#   ('buget', 'NN'),
#   ('sealed', 'VBD'),
#   ('box', 'RB'),
#   ('good', 'JJ'),
#   ('accessorise', 'NN'),
#   ('smart', 'JJ'),
#   ('coverread', 'NN')],
#  [('good', 'JJ'),
#   ('phone', 'NN'),
#   ('good', 'JJ'),
#   ('battery', 'NN'),
#   ('good', 'JJ'),
#   ('display', 'NN'),
#   ('good', 'JJ'),
#   ('camera', 'NN'),
#   ('watt', 'NN'),
#   ('charging', 'VBG'),
#   ('speed', 'NN'),
#   ('loved', 'VBN'),
#   ('itread', 'NN')],
#  [('first', 'RB'),
#   ('im', 'VBZ'),
#   ('going', 'VBG'),
#   ('tell', 'VB'),
#   ('speed', 'VB'),
#   ('flipkart', 'RB'),
#   ('delivered', 'VBN'),
#   ('product', 'NN'),
#   ('within', 'IN'),
#   ('hour', 'NN'),
#   ('first', 'RB'),
#   ('impressed', 'JJ'),
#   ('superb', 'NN'),
#   ('packagingim', 'NN'),
#   ('writing', 'VBG'),
#   ('review', 'JJ'),
#   ('usage', 'JJ'),
#   ('day', 'NN'),
#   ('let', 'VB'),
#   ('talk', 'VB'),
#   ('overall', 'JJ'),
#   ('performancequalitybuildindesignwe', 'NN'),
#   ('appreciate', 'NN'),
#   ('ram', 'NN'),
#   ('managementthe', 'NN'),
#   ('ram', 'NN'),
#   ('management', 'NN'),
#   ('boom', 'NN'),
#   ('performance', 'NN'),
#   ('processor', 'NN'),
#   ('mediatek', 'NN'),
#   ('helio', 'NN'),
#   ('g', 'VBD'),
#   ('awesome', 'JJ'),
#   ('run', 'NN'),
#   ('game', 'NN'),
#   ('soo', 'RB'),
#   ('well', 'RB'),
#   ('without', 'IN'),
#   ('heating', 'VBG'),
#   ('issuenow', 'JJ'),
#   ('move', 'NN'),
#   ('camread', 'NN')],
#  [('super', 'JJ'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('fast', 'RB'),
#   ('charging', 'VBG'),
#   ('awesome', 'JJ'),
#   ('phone', 'NN'),
#   ('loved', 'VBD'),
#   ('itread', 'NN')],
#  [('think', 'VB'),
#   ('price', 'NN'),
#   ('high', 'JJ'),
#   ('phone', 'NN'),
#   ('well', 'RB'),
#   ('expected', 'VBN'),
#   ('slow', 'JJ'),
#   ('mo', 'NN'),
#   ('new', 'JJ'),
#   ('feature', 'NN'),
#   ('mobile', 'JJ'),
#   ('camera', 'NN'),
#   ('lightness', 'NN'),
#   ('think', 'VBP'),
#   ('oppo', 'IN'),
#   ('reno', 'NN'),
#   ('camera', 'NN'),
#   ('better', 'RBR'),
#   ('realme', 'NN'),
#   ('display', 'NN'),
#   ('feature', 'NN'),
#   ('clear', 'JJ'),
#   ('realme', 'NN'),
#   ('pohneread', 'NN')],
#  [('writing', 'VBG'),
#   ('review', 'NN'),
#   ('day', 'NN'),
#   ('usagebenefits', 'VBZ'),
#   ('first', 'RB'),
#   ('grt', 'JJ'),
#   ('performance', 'NN'),
#   ('superb', 'NN'),
#   ('game', 'NN'),
#   ('play', 'NN'),
#   ('lag', 'NN'),
#   ('pubg', 'NN'),
#   ('play', 'NN'),
#   ('camera', 'NN'),
#   ('best', 'JJS'),
#   ('finger', 'NN'),
#   ('print', 'NN'),
#   ('unlock', 'NN'),
#   ('best', 'JJS'),
#   ('face', 'NN'),
#   ('unlock', 'NN'),
#   ('apps', 'NN'),
#   ('loved', 'VBD'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('battery', 'NN'),
#   ('full', 'JJ'),
#   ('le', 'NN'),
#   ('thn', 'NN'),
#   ('min', 'NN'),
#   ('disadvantage', 'NN'),
#   ('sometimes', 'RB'),
#   ('apps', 'JJ'),
#   ('auto', 'NN'),
#   ('get', 'NN'),
#   ('closed', 'VBD'),
#   ('batter', 'NN'),
#   ('feel', 'NN'),
#   ('gd', 'RB'),
#   ('vigerous', 'JJ'),
#   ('user', 'NN'),
#   ('touch', 'NN'),
#   ('sometimes', 'RB'),
#   ('low', 'JJ'),
#   ('u', 'JJ'),
#   ('need', 'NN'),
#   ('fully', 'RB'),
#   ('hve', 'JJ'),
#   ('ur', 'JJ'),
#   ('skin', 'NN'),
#   ('touchoverall', 'NN'),
#   ('must', 'MD'),
#   ('buy', 'VB'),
#   ('mobile', 'JJ'),
#   ('u', 'JJ'),
#   ('think', 'VBP'),
#   ('firread', 'JJ')],
#  [('good', 'JJ'),
#   ('product', 'NN'),
#   ('nice', 'JJ'),
#   ('quality', 'NN'),
#   ('best', 'JJS'),
#   ('thank', 'JJ'),
#   ('flipkart', 'NN'),
#   ('read', 'NN')],
#  [('superb', 'JJ'),
#   ('quality', 'NN'),
#   ('best', 'JJS'),
#   ('performance', 'NN'),
#   ('good', 'JJ'),
#   ('camera', 'NN'),
#   ('best', 'JJS'),
#   ('worth', 'NN'),
#   ('read', 'NN')],
#  [('color', 'NN'),
#   ('mentioned', 'VBD'),
#   ('white', 'JJ'),
#   ('quite', 'RB'),
#   ('like', 'JJ'),
#   ('light', 'JJ'),
#   ('blue', 'NN'),
#   ('sky', 'NN'),
#   ('bluecamera', 'NN'),
#   ('good', 'JJ'),
#   ('undoubtedlyw', 'NN'),
#   ('charging', 'VBG'),
#   ('also', 'RB'),
#   ('goodphone', 'NN'),
#   ('fast', 'JJ'),
#   ('tooi', 'JJ'),
#   ('focus', 'NN'),
#   ('ui', 'JJ'),
#   ('loophole', 'JJ'),
#   ('dont', 'NN'),
#   ('like', 'IN'),
#   ('firstly', 'RB'),
#   ('irritating', 'VBG'),
#   ('keyboard', 'NN'),
#   ('using', 'VBG'),
#   ('samsung', 'JJ'),
#   ('phone', 'NN'),
#   ('previously', 'RB'),
#   ('buyed', 'VBN'),
#   ('keyboard', 'NN'),
#   ('experience', 'NN'),
#   ('bad', 'JJ'),
#   ('type', 'NN'),
#   ('something', 'NN'),
#   ('else', 'RB'),
#   ('understands', 'VBZ'),
#   ('something', 'NN'),
#   ('elsealso', 'JJ'),
#   ('u', 'JJ'),
#   ('cant', 'NN'),
#   ('adjust', 'VBP'),
#   ('keyboard', 'NN'),
#   ('height', 'NN'),
#   ('screen', 'NN'),
#   ('size', 'NN'),
#   ('big', 'JJ'),
#   ('keyboard', 'NN'),
#   ('small', 'JJ'),
#   ('handread', 'NN')],
#  [('reviewing', 'VBG'),
#   ('monthsits', 'NNS'),
#   ('really', 'RB'),
#   ('good', 'JJ'),
#   ('overall', 'JJ'),
#   ('phone', 'NN'),
#   ('worth', 'NN'),
#   ('good', 'JJ'),
#   ('camera', 'NN'),
#   ('durable', 'JJ'),
#   ('battery', 'NN'),
#   ('fast', 'RB'),
#   ('charging', 'VBG'),
#   ('best', 'JJS'),
#   ('performance', 'NN'),
#   ('according', 'VBG'),
#   ('pricegaming', 'VBG'),
#   ('also', 'RB'),
#   ('goodread', 'NN')],
#  [('good', 'JJ'),
#   ('camera', 'NN'),
#   ('decent', 'NN'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('smooth', 'JJ'),
#   ('display', 'NN'),
#   ('switched', 'VBD'),
#   ('hz', 'JJ'),
#   ('hz', 'NN'),
#   ('display', 'NN'),
#   ('feel', 'NN'),
#   ('goodread', 'NN')],
#  [('nice', 'JJ'),
#   ('product', 'NN'),
#   ('really', 'RB'),
#   ('impressed', 'JJ'),
#   ('good', 'JJ'),
#   ('performance', 'NN'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('improve', 'VB'),
#   ('camera', 'NN'),
#   ('ossum', 'IN'),
#   ('ovarally', 'RB'),
#   ('good', 'JJ'),
#   ('phoneread', 'NN')],
#  [('first', 'RB'),
#   ('delivered', 'VBN'),
#   ('mobile', 'RB'),
#   ('set', 'VBN'),
#   ('working', 'VBG'),
#   ('fine', 'NN'),
#   ('replaced', 'VBD'),
#   ('nd', 'JJ'),
#   ('one', 'CD'),
#   ('also', 'RB'),
#   ('working', 'VBG'),
#   ('well', 'RB'),
#   ('sometimes', 'RB'),
#   ('touch', 'JJ'),
#   ('sensibility', 'NN'),
#   ('work', 'NN'),
#   ('fineread', 'NN')],
#  [('realme', 'NN'),
#   ('mobile', 'RB'),
#   ('good', 'JJ'),
#   ('camera', 'NN'),
#   ('battery', 'NN'),
#   ('display', 'NN'),
#   ('value', 'NN'),
#   ('money', 'NN'),
#   ('performance', 'NN'),
#   ('camera', 'NN'),
#   ('really', 'RB'),
#   ('superbattery', 'JJ'),
#   ('charging', 'VBG'),
#   ('minute', 'NN'),
#   ('full', 'JJ'),
#   ('charging', 'VBG'),
#   ('w', 'NN'),
#   ('fast', 'RB'),
#   ('chargingbattery', 'JJ'),
#   ('use', 'NN'),
#   ('normal', 'JJ'),
#   ('use', 'NN'),
#   ('dayinternet', 'NN'),
#   ('use', 'NN'),
#   ('day', 'NN'),
#   ('full', 'JJ'),
#   ('use', 'NN'),
#   ('display', 'NN'),
#   ('super', 'JJ'),
#   ('goodall', 'NN'),
#   ('performance', 'NN'),
#   ('super', 'VBD'),
#   ('good', 'JJ'),
#   ('excellentread', 'NN')],
#  [('must', 'MD'),
#   ('read', 'VB'),
#   ('review', 'VB'),
#   ('seeing', 'VBG'),
#   ('star', 'JJ'),
#   ('reviewswhy', 'NN'),
#   ('giving', 'VBG'),
#   ('star', 'NN'),
#   ('simplest', 'JJS'),
#   ('answer', 'NN'),
#   ('maybe', 'RB'),
#   ('didnt', 'JJ'),
#   ('liked', 'VBD'),
#   ('loved', 'VBN'),
#   ('retailer', 'NN'),
#   ('purchasing', 'VBG'),
#   ('selling', 'VBG'),
#   ('store', 'NN'),
#   ('higher', 'JJR'),
#   ('price', 'NN'),
#   ('thus', 'RB'),
#   ('give', 'VB'),
#   ('star', 'NN'),
#   ('people', 'NNS'),
#   ('lose', 'VBP'),
#   ('confidence', 'NN'),
#   ('phone', 'NN'),
#   ('get', 'NN'),
#   ('best', 'JJS'),
#   ('chance', 'NN'),
#   ('ongoing', 'VBG'),
#   ('boycott', 'JJ'),
#   ('china', 'NN'),
#   ('kind', 'NN'),
#   ('thing', 'NN'),
#   ('people', 'NNS'),
#   ('still', 'RB'),
#   ('blinded', 'VBN'),
#   ('hatred', 'VBN'),
#   ('giving', 'VBG'),
#   ('star', 'NN'),
#   ('promote', 'VBP'),
#   ('indigenous', 'JJ'),
#   ('mobileswhich', 'NNS'),
#   ('good', 'JJ'),
#   ('indigenous', 'JJ'),
#   ('read', 'NN')],
#  [('month', 'NN'),
#   ('use', 'NN'),
#   ('battery', 'NN'),
#   ('perfect', 'NN'),
#   ('long', 'RB'),
#   ('lasting', 'JJ'),
#   ('camera', 'NN'),
#   ('great', 'JJ'),
#   ('colour', 'JJ'),
#   ('quantity', 'NN'),
#   ('slightly', 'RB'),
#   ('poordisplay', 'VBZ'),
#   ('comfortable', 'JJ'),
#   ('navigation', 'NN'),
#   ('key', 'JJ'),
#   ('doesent', 'JJ'),
#   ('work', 'NN'),
#   ('properly', 'RB'),
#   ('time', 'NN'),
#   ('overall', 'JJ'),
#   ('performance', 'NN'),
#   ('great', 'JJ'),
#   ('time', 'NN'),
#   ('slowread', 'NN')],
#  [('reviewing', 'VBG'),
#   ('month', 'NN'),
#   ('purchasecamera', 'RB'),
#   ('much', 'RB'),
#   ('optimised', 'VBN'),
#   ('beginning', 'VBG'),
#   ('frequent', 'JJ'),
#   ('update', 'JJ'),
#   ('getting', 'VBG'),
#   ('betterbattery', 'NN'),
#   ('really', 'RB'),
#   ('surprised', 'JJ'),
#   ('device', 'NN'),
#   ('beast', 'NN'),
#   ('processor', 'NN'),
#   ('top', 'JJ'),
#   ('class', 'NN'),
#   ('stuff', 'NN'),
#   ('afterall', 'NN'),
#   ('get', 'VB'),
#   ('atleast', 'JJ'),
#   ('hr', 'NN'),
#   ('screen', 'NN'),
#   ('time', 'NN'),
#   ('without', 'IN'),
#   ('battery', 'NN'),
#   ('saver', 'NN'),
#   ('including', 'VBG'),
#   ('gaming', 'VBG'),
#   ('hz', 'NN'),
#   ('rr', 'NN'),
#   ('always', 'RB'),
#   ('charging', 'VBG'),
#   ('good', 'JJ'),
#   ('get', 'NN'),
#   ('minute', 'JJ'),
#   ('observationsthanks', 'NNS'),
#   ('g', 'VBP'),
#   ('processor', 'NN'),
#   ('giving', 'VBG'),
#   ('uninterrupt', 'JJ'),
#   ('performance', 'NN'),
#   ('dread', 'NN')],
#  [('camera', 'NN'),
#   ('good', 'JJ'),
#   ('goodbattary', 'JJ'),
#   ('nice', 'JJ'),
#   ('performance', 'NN'),
#   ('aswm', 'IN'),
#   ('overall', 'JJ'),
#   ('good', 'JJ'),
#   ('package', 'NN'),
#   ('camera', 'NN'),
#   ('need', 'VBP'),
#   ('improvementread', 'NN')],
#  [('toooo', 'RB'),
#   ('good', 'JJ'),
#   ('realme', 'NN'),
#   ('really', 'RB'),
#   ('amazed', 'JJ'),
#   ('everywaycamera', 'NN'),
#   ('battery', 'NN'),
#   ('display', 'NN'),
#   ('performance', 'NN'),
#   ('user', 'JJ'),
#   ('experience', 'NN'),
#   ('cant', 'NN'),
#   ('put', 'VBD'),
#   ('device', 'RB'),
#   ('handthis', 'RB'),
#   ('good', 'JJ'),
#   ('price', 'NN'),
#   ('paid', 'VBD'),
#   ('coz', 'NN'),
#   ('got', 'VBD'),
#   ('exchange', 'NN'),
#   ('older', 'NN'),
#   ('device', 'NN'),
#   ('thanks', 'NNS'),
#   ('flipkart', 'VBP'),
#   ('thati', 'JJ'),
#   ('recommend', 'VBP'),
#   ('device', 'NN'),
#   ('want', 'VBP'),
#   ('allrounder', 'NN'),
#   ('phone', 'NN'),
#   ('two', 'CD'),
#   ('tip', 'NN'),
#   ('usersplease', 'JJ'),
#   ('update', 'JJ'),
#   ('phone', 'NN'),
#   ('soon', 'RB'),
#   ('possible', 'JJ'),
#   ('becausethere', 'JJ'),
#   ('ghost', 'NN'),
#   ('touch', 'JJ'),
#   ('screen', 'NN'),
#   ('flickering', 'VBG'),
#   ('issue', 'NN'),
#   ('device', 'NN'),
#   ('also', 'RB'),
#   ('faced', 'VBD'),
#   ('ghost', 'NN'),
#   ('toucread', 'NN')],
#  [('awesome', 'JJ'),
#   ('phone', 'NN'),
#   ('pricedisplay', 'NN'),
#   ('creating', 'VBG'),
#   ('issue', 'NN'),
#   ('swiping', 'VBG'),
#   ('camera', 'NN'),
#   ('awesome', 'JJ'),
#   ('sony', 'NN'),
#   ('sensor', 'NN'),
#   ('look', 'VBP'),
#   ('mist', 'JJ'),
#   ('blue', 'JJ'),
#   ('amazingneed', 'NN'),
#   ('work', 'NN'),
#   ('display', 'NN'),
#   ('refresh', 'JJ'),
#   ('rate', 'NN'),
#   ('performing', 'VBG'),
#   ('hz', 'JJ'),
#   ('refresh', 'JJ'),
#   ('rate', 'NN'),
#   ('displayread', 'NN')],
#  [('phone', 'NN'),
#   ('really', 'RB'),
#   ('fast', 'RB'),
#   ('amazing', 'JJ'),
#   ('selfie', 'NN'),
#   ('camera', 'NN'),
#   ('good', 'NN'),
#   ('also', 'RB'),
#   ('like', 'IN'),
#   ('overall', 'JJ'),
#   ('performanceread', 'NN')],
#  [('realme', 'NN'),
#   ('best', 'JJS'),
#   ('display', 'NN'),
#   ('average', 'NN'),
#   ('camera', 'NN'),
#   ('good', 'JJ'),
#   ('charging', 'VBG'),
#   ('fast', 'RB'),
#   ('battery', 'NN'),
#   ('beckup', 'NN'),
#   ('goodread', 'NN')],
#  [('writnig', 'RB'),
#   ('review', 'VB'),
#   ('month', 'NN'),
#   ('use', 'NN'),
#   ('battery', 'NN'),
#   ('great', 'JJ'),
#   ('half', 'JJ'),
#   ('day', 'NN'),
#   ('performance', 'NN'),
#   ('mode', 'VBD'),
#   ('day', 'NN'),
#   ('normal', 'JJ'),
#   ('use', 'NN'),
#   ('watt', 'NN'),
#   ('vooc', 'JJ'),
#   ('charge', 'NN'),
#   ('great', 'JJ'),
#   ('charge', 'NN'),
#   ('fast', 'JJ'),
#   ('speedcamera', 'NN'),
#   ('nice', 'JJ'),
#   ('add', 'NN'),
#   ('imagesdisplay', 'VB'),
#   ('good', 'JJ'),
#   ('time', 'NN'),
#   ('screen', 'JJ'),
#   ('fluctuateed', 'VBN'),
#   ('fixed', 'VBN'),
#   ('updatesfor', 'JJ'),
#   ('gaming', 'NN'),
#   ('best', 'JJS'),
#   ('priceread', 'NN')],
#  [('purchased', 'VBN'),
#   ('k', 'NNS'),
#   ('one', 'CD'),
#   ('month', 'NN'),
#   ('ago', 'RB'),
#   ('best', 'JJS'),
#   ('value', 'NN'),
#   ('money', 'NN'),
#   ('phone', 'NN'),
#   ('rear', 'VBP'),
#   ('camera', 'NN'),
#   ('sensor', 'NN'),
#   ('sony', 'NN'),
#   ('imx', 'NN'),
#   ('powerful', 'JJ'),
#   ('sensor', 'JJ'),
#   ('capture', 'NN'),
#   ('light', 'NN'),
#   ('dark', 'NN'),
#   ('however', 'RB'),
#   ('image', 'NN'),
#   ('processing', 'VBG'),
#   ('need', 'NN'),
#   ('tweaked', 'VBD'),
#   ('software', 'NN'),
#   ('update', 'JJ'),
#   ('take', 'VB'),
#   ('full', 'JJ'),
#   ('advantage', 'NN'),
#   ('sensor', 'NN'),
#   ('installing', 'VBG'),
#   ('gcam', 'JJ'),
#   ('solves', 'NNS'),
#   ('camera', 'VBP'),
#   ('related', 'VBN'),
#   ('problem', 'NN'),
#   ('got', 'VBD'),
#   ('several', 'JJ'),
#   ('software', 'NN'),
#   ('update', 'JJ'),
#   ('far', 'RB'),
#   ('fix', 'JJ'),
#   ('several', 'JJ'),
#   ('issue', 'NN'),
#   ('display', 'VBD'),
#   ('touch', 'JJ'),
#   ('camera', 'NN'),
#   ('battery', 'NN'),
#   ('performance', 'NN'),
#   ('still', 'RB'),
#   ('issue', 'VB'),
#   ('read', 'NN')],
#  [('nice', 'JJ'),
#   ('phone', 'NN'),
#   ('realme', 'NN'),
#   ('fast', 'RB'),
#   ('charging', 'VBG'),
#   ('phone', 'NN'),
#   ('quality', 'NN'),
#   ('e', 'NN'),
#   ('nice', 'JJ'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('awesomeread', 'NN')],
#  [('nice', 'RB'),
#   ('mobile', 'JJ'),
#   ('specially', 'RB'),
#   ('camera', 'NN'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('processor', 'NN'),
#   ('awesome', 'VBP'),
#   ('really', 'RB'),
#   ('loved', 'VBN'),
#   ('itread', 'NN')],
#  [('read', 'VB'),
#   ('buyingthe', 'NN'),
#   ('phone', 'NN'),
#   ('great', 'JJ'),
#   ('charging', 'VBG'),
#   ('speed', 'NN'),
#   ('backup', 'NN'),
#   ('amazing', 'VBG'),
#   ('far', 'RB'),
#   ('speaker', 'NN'),
#   ('great', 'JJ'),
#   ('quality', 'NN'),
#   ('dont', 'NN'),
#   ('use', 'NN'),
#   ('camera', 'NN'),
#   ('much', 'RB'),
#   ('neither', 'CC'),
#   ('play', 'VB'),
#   ('game', 'NN'),
#   ('cant', 'JJ'),
#   ('comment', 'NN'),
#   ('phone', 'NN'),
#   ('issue', 'NN'),
#   ('popup', 'NN'),
#   ('ad', 'NN'),
#   ('every', 'DT'),
#   ('hour', 'NN'),
#   ('major', 'JJ'),
#   ('issue', 'NN'),
#   ('wifi', 'NN'),
#   ('link', 'VBP'),
#   ('speed', 'NN'),
#   ('fixed', 'VBN'),
#   ('mbps', 'JJ'),
#   ('ghz', 'NN'),
#   ('reason', 'NN'),
#   ('ive', 'JJ'),
#   ('mbps', 'NN'),
#   ('connection', 'NN'),
#   ('home', 'NN'),
#   ('maximum', 'NN'),
#   ('get', 'VBP'),
#   ('mbps', 'JJ'),
#   ('setting', 'VBG'),
#   ('visible', 'JJ'),
#   ('searching', 'VBG'),
#   ('keyword', 'NN'),
#   ('cant', 'NN'),
#   ('scrolleread', 'NN')],
#  [('initially', 'RB'),
#   ('phone', 'NN'),
#   ('got', 'VBD'),
#   ('problem', 'NN'),
#   ('ghost', 'NN'),
#   ('screen', 'NN'),
#   ('glitch', 'NN'),
#   ('update', 'JJ'),
#   ('awesome', 'JJ'),
#   ('completely', 'RB'),
#   ('satisfied', 'VBD'),
#   ('phone', 'NN'),
#   ('love', 'NN'),
#   ('cool', 'NN'),
#   ('fastest', 'JJS'),
#   ('charging', 'VBG'),
#   ('performance', 'NN'),
#   ('awesomeno', 'JJ'),
#   ('lag', 'NN'),
#   ('camera', 'NN'),
#   ('lover', 'NN'),
#   ('camera', 'NN'),
#   ('great', 'JJ'),
#   ('sense', 'NN'),
#   ('everything', 'NN'),
#   ('great', 'JJ'),
#   ('anyone', 'NN'),
#   ('go', 'VBP'),
#   ('itread', 'NN')],
#  [('mobile', 'RB'),
#   ('good', 'JJ'),
#   ('worth', 'NN'),
#   ('money', 'NN'),
#   ('battery', 'NN'),
#   ('awesome', 'VBP'),
#   ('charging', 'VBG'),
#   ('fast', 'RB'),
#   ('minits', 'NNS'),
#   ('camera', 'VBP'),
#   ('awesomeread', 'NN')],
#  [('prabhas', 'NN'),
#   ('hari', 'NN'),
#   ('nice', 'JJ'),
#   ('mobile', 'JJ'),
#   ('super', 'JJ'),
#   ('quality', 'NN'),
#   ('super', 'IN'),
#   ('fast', 'JJ'),
#   ('battery', 'NN'),
#   ('charging', 'VBG'),
#   ('nice', 'JJ'),
#   ('quality', 'NN'),
#   ('camera', 'NN'),
#   ('use', 'NN'),
#   ('setting', 'VBG'),
#   ('super', 'NNS'),
#   ('like', 'IN'),
#   ('thisfriendsread', 'NN')],
#  [('im', 'NN'),
#   ('writing', 'VBG'),
#   ('review', 'NN'),
#   ('using', 'VBG'),
#   ('two', 'CD'),
#   ('month', 'NN'),
#   ('overall', 'JJ'),
#   ('device', 'NN'),
#   ('performance', 'NN'),
#   ('goodthe', 'NN'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('superb', 'NN'),
#   ('bought', 'VBD'),
#   ('phone', 'NN'),
#   ('r', 'NN'),
#   ('price', 'NN'),
#   ('reasonableand', 'NN'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('bit', 'NN'),
#   ('disappointing', 'JJ'),
#   ('good', 'JJ'),
#   ('charging', 'NN'),
#   ('time', 'NN'),
#   ('min', 'NN'),
#   ('gaming', 'VBG'),
#   ('purpose', 'NN'),
#   ('like', 'IN'),
#   ('cod', 'NN'),
#   ('pubg', 'NN'),
#   ('game', 'NN'),
#   ('also', 'RB'),
#   ('supporting', 'VBG'),
#   ('graphic', 'NNS'),
#   ('also', 'RB'),
#   ('good', 'JJ'),
#   ('recommend', 'NN'),
#   ('u', 'JJ'),
#   ('u', 'NN'),
#   ('want', 'VBP'),
#   ('buy', 'NN'),
#   ('mobile', 'JJ'),
#   ('k', 'NN'),
#   ('u', 'NN'),
#   ('may', 'MD'),
#   ('go', 'VB'),
#   ('phoneread', 'NN')],
#  [('camera', 'NN'),
#   ('good', 'JJ'),
#   ('best', 'JJS'),
#   ('like', 'IN'),
#   ('sony', 'NN'),
#   ('pixel', 'NN'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('bad', 'JJ'),
#   ('look', 'NN'),
#   ('goodfast', 'NN'),
#   ('charging', 'VBG'),
#   ('goodread', 'NN')],
#  [('image', 'NN'),
#   ('clearspeaker', 'NN'),
#   ('bad', 'JJ'),
#   ('quality', 'NN'),
#   ('sound', 'NN'),
#   ('clear', 'JJ'),
#   ('phone', 'NN'),
#   ('little', 'JJ'),
#   ('bit', 'NN'),
#   ('got', 'VBD'),
#   ('hanged', 'VBN'),
#   ('hz', 'JJ'),
#   ('refresh', 'JJ'),
#   ('rate', 'NN'),
#   ('properly', 'JJ'),
#   ('work', 'NN'),
#   ('appsread', 'NN')],
#  [('phone', 'NN'),
#   ('good', 'JJ'),
#   ('medium', 'NN'),
#   ('tek', 'NN'),
#   ('processor', 'NN'),
#   ('best', 'JJS'),
#   ('always', 'RB'),
#   ('recommend', 'VB'),
#   ('snapdragon', 'NN'),
#   ('processor', 'NN'),
#   ('medium', 'NN'),
#   ('tek', 'NN'),
#   ('processor', 'NN'),
#   ('tube', 'NN'),
#   ('video', 'NN'),
#   ('good', 'JJ'),
#   ('plying', 'NN'),
#   ('performance', 'NN'),
#   ('voice', 'NN'),
#   ('play', 'NN'),
#   ('first', 'RB'),
#   ('picture', 'NN'),
#   ('later', 'RB'),
#   ('second', 'JJ'),
#   ('badread', 'NN')],
#  [('osm', 'IN'),
#   ('phone', 'NN'),
#   ('cro', 'NN'),
#   ('dont', 'JJ'),
#   ('notification', 'NN'),
#   ('light', 'VBD'),
#   ('come', 'JJ'),
#   ('gorilla', 'NN'),
#   ('glass', 'NN'),
#   ('front', 'NN'),
#   ('camera', 'NN'),
#   ('could', 'MD'),
#   ('better', 'VB'),
#   ('pro', 'JJ'),
#   ('super', 'FW'),
#   ('fast', 'RB'),
#   ('smoot', 'JJ'),
#   ('best', 'JJS'),
#   ('gaming', 'VBG'),
#   ('good', 'JJ'),
#   ('display', 'NN'),
#   ('gz', 'NN'),
#   ('refresh', 'JJ'),
#   ('rate', 'NN'),
#   ('nice', 'JJ'),
#   ('camera', 'NN'),
#   ('mpread', 'NN')],
#  [('good', 'JJ'),
#   ('one', 'CD'),
#   ('rsbattery', 'NN'),
#   ('fantastic', 'JJ'),
#   ('charging', 'VBG'),
#   ('speed', 'NN'),
#   ('awesome', 'JJ'),
#   ('camera', 'NN'),
#   ('average', 'NN'),
#   ('nd', 'JJ'),
#   ('screen', 'JJ'),
#   ('good', 'JJ'),
#   ('performance', 'NN'),
#   ('wise', 'NN'),
#   ('average', 'NN'),
#   ('overall', 'JJ'),
#   ('good', 'JJ'),
#   ('oneread', 'NN')],
#  [('giving', 'VBG'),
#   ('review', 'NN'),
#   ('using', 'VBG'),
#   ('month', 'NN'),
#   ('good', 'JJ'),
#   ('feature', 'NN'),
#   ('phone', 'NN'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('battery', 'NN'),
#   ('longlasting', 'VBG'),
#   ('display', 'NN'),
#   ('full', 'JJ'),
#   ('hd', 'NN'),
#   ('would', 'MD'),
#   ('awesome', 'VB'),
#   ('provided', 'VBD'),
#   ('amoled', 'JJ'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('hertz', 'NN'),
#   ('refresh', 'JJ'),
#   ('rate', 'NN'),
#   ('give', 'VB'),
#   ('awesome', 'JJ'),
#   ('experience', 'NN'),
#   ('loving', 'VBG'),
#   ('itin', 'NN'),
#   ('nutshell', 'RB'),
#   ('best', 'RB'),
#   ('phone', 'NN'),
#   ('buy', 'NN'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('good', 'JJ'),
#   ('dont', 'NN'),
#   ('go', 'VBP'),
#   ('chinese', 'JJ'),
#   ('phonesread', 'NN')],
#  [('front', 'JJ'),
#   ('camera', 'NN'),
#   ('overly', 'RB'),
#   ('exposing', 'VBG'),
#   ('like', 'IN'),
#   ('white', 'JJ'),
#   ('smooth', 'JJ'),
#   ('dont', 'NN'),
#   ('like', 'IN'),
#   ('natural', 'JJ'),
#   ('always', 'RB'),
#   ('beautiful', 'JJ'),
#   ('hope', 'NN'),
#   ('fix', 'NN'),
#   ('software', 'NN'),
#   ('updateread', 'JJ')],
#  [('phone', 'NN'),
#   ('best', 'JJS'),
#   ('camera', 'NN'),
#   ('best', 'RBS'),
#   ('battery', 'NN'),
#   ('best', 'JJS'),
#   ('performance', 'NN'),
#   ('based', 'VBN'),
#   ('bestread', 'NN')],
#  [('dont', 'NN'),
#   ('know', 'VBP'),
#   ('certain', 'JJ'),
#   ('reason', 'NN'),
#   ('macro', 'NN'),
#   ('lens', 'VBZ'),
#   ('good', 'JJ'),
#   ('enough', 'RB'),
#   ('try', 'NN'),
#   ('capture', 'NN'),
#   ('image', 'NN'),
#   ('closer', 'NN'),
#   ('range', 'NN'),
#   ('bluring', 'VBG'),
#   ('face', 'NN'),
#   ('lock', 'NN'),
#   ('doesnt', 'NN'),
#   ('work', 'NN'),
#   ('vey', 'RB'),
#   ('good', 'JJ'),
#   ('performance', 'NN'),
#   ('mobile', 'RB'),
#   ('good', 'JJ'),
#   ('enough', 'RB'),
#   ('still', 'RB'),
#   ('quite', 'RB'),
#   ('problemsread', 'JJ')],
#  [('month', 'NN'),
#   ('use', 'NN'),
#   ('notice', 'NN'),
#   ('screen', 'NN'),
#   ('flikering', 'VBG'),
#   ('proper', 'JJ'),
#   ('fix', 'NNS'),
#   ('touch', 'JJ'),
#   ('response', 'NN'),
#   ('good', 'JJ'),
#   ('bt', 'NN'),
#   ('time', 'NN'),
#   ('auto', 'NN'),
#   ('touch', 'RB'),
#   ('anywhere', 'RB'),
#   ('screen', 'JJ'),
#   ('battery', 'NN'),
#   ('draining', 'VBG'),
#   ('fast', 'RB'),
#   ('without', 'IN'),
#   ('using', 'VBG'),
#   ('game', 'NN'),
#   ('hour', 'NN'),
#   ('useable', 'JJ'),
#   ('internet', 'NN'),
#   ('medium', 'NN'),
#   ('full', 'JJ'),
#   ('chargeread', 'NN')],
#  [('phone', 'NN'),
#   ('performance', 'NN'),
#   ('slightly', 'RB'),
#   ('lower', 'JJR'),
#   ('expectedfront', 'NN'),
#   ('camera', 'NN'),
#   ('good', 'JJ'),
#   ('selfie', 'NN'),
#   ('camera', 'NN'),
#   ('require', 'VBP'),
#   ('clear', 'JJ'),
#   ('picture', 'NN'),
#   ('expected', 'VBN'),
#   ('gb', 'JJ'),
#   ('ram', 'NN'),
#   ('fast', 'NN'),
#   ('sometimes', 'RB'),
#   ('lagging', 'JJ'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('day', 'NN'),
#   ('drain', 'VB'),
#   ('automaticallyw', 'IN'),
#   ('charging', 'VBG'),
#   ('feature', 'NN'),
#   ('fastfingerprint', 'NN'),
#   ('working', 'VBG'),
#   ('properlydisplay', 'NN'),
#   ('upto', 'JJ'),
#   ('mark', 'NN'),
#   ('also', 'RB'),
#   ('working', 'VBG'),
#   ('properly', 'RB'),
#   ('like', 'IN'),
#   ('previous', 'JJ'),
#   ('realme', 'JJ'),
#   ('pro', 'FW'),
#   ('phonedont', 'FW'),
#   ('waste', 'NN'),
#   ('money', 'NN'),
#   ('devicethanks', 'NNS'),
#   ('flipkart', 'VBP'),
#   ('delivering', 'VBG'),
#   ('fast', 'RB'),
#   ('read', 'VB')],
#  [('using', 'VBG'),
#   ('realme', 'NN'),
#   ('last', 'JJ'),
#   ('month', 'NN'),
#   ('time', 'NN'),
#   ('face', 'VBP'),
#   ('issue', 'NN'),
#   ('like', 'IN'),
#   ('diaplay', 'NN'),
#   ('flickering', 'VBG'),
#   ('hangjng', 'JJ'),
#   ('issue', 'NN'),
#   ('like', 'IN'),
#   ('rumour', 'JJ'),
#   ('gamer', 'NN'),
#   ('faced', 'VBD'),
#   ('issue', 'NN'),
#   ('processing', 'NN'),
#   ('like', 'IN'),
#   ('gameplays', 'NNS'),
#   ('like', 'IN'),
#   ('heating', 'VBG'),
#   ('issue', 'NN'),
#   ('low', 'JJ'),
#   ('performance', 'NN'),
#   ('minute', 'NN'),
#   ('gameplay', 'NN'),
#   ('processor', 'NN'),
#   ('give', 'VBP'),
#   ('constant', 'JJ'),
#   ('speed', 'NN'),
#   ('gamjng', 'NN'),
#   ('getting', 'VBG'),
#   ('worst', 'JJS'),
#   ('vames', 'NNS'),
#   ('lkke', 'VBP'),
#   ('call', 'VB'),
#   ('duty', 'NN'),
#   ('pubg', 'NN'),
#   ('work', 'NN'),
#   ('good', 'JJ'),
#   ('heavy', 'JJ'),
#   ('game', 'NN'),
#   ('like', 'IN'),
#   ('genshin', 'JJ'),
#   ('impact', 'NN'),
#   ('jot', 'NN'),
#   ('read', 'NN')],
#  [('nice', 'JJ'),
#   ('phone', 'NN'),
#   ('photo', 'NN'),
#   ('also', 'RB'),
#   ('nice', 'JJ'),
#   ('liked', 'VBD'),
#   ('phone', 'NN'),
#   ('read', 'NN')],
#  [('nice', 'JJ'), ('cameraread', 'NN')],
#  [('camera', 'NN'),
#   ('good', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('bokeh', 'NN'),
#   ('excellentread', 'NN')],
#  [('nice', 'JJ'), ('camera', 'NN'), ('read', 'NN')],
#  [('good', 'JJ'), ('productread', 'NN')],
#  [('nice', 'JJ'),
#   ('product', 'NN'),
#   ('great', 'JJ'),
#   ('camerabattery', 'NN'),
#   ('goodread', 'NN')],
#  [('worth', 'JJ'), ('price', 'NN'), ('lyked', 'VBD'), ('itread', 'JJ')],
#  [('good', 'JJ'),
#   ('product', 'NN'),
#   ('posting', 'VBG'),
#   ('review', 'NN'),
#   ('week', 'NN'),
#   ('usagebattery', 'JJ'),
#   ('last', 'JJ'),
#   ('day', 'NN'),
#   ('average', 'JJ'),
#   ('use', 'NN'),
#   ('good', 'JJ'),
#   ('resolution', 'NN'),
#   ('playing', 'VBG'),
#   ('videosread', 'NN')],
#  [('nice', 'JJ'), ('phread', 'NN')],
#  [('touch', 'JJ'),
#   ('automatically', 'RB'),
#   ('stop', 'JJ'),
#   ('response', 'NN'),
#   ('smoothlyread', 'NN')],
#  [('processing', 'VBG'),
#   ('speed', 'NN'),
#   ('good', 'JJ'),
#   ('ggaming', 'VBG'),
#   ('speed', 'NN'),
#   ('fast', 'RB'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('averageall', 'JJ'),
#   ('feature', 'NN'),
#   ('good', 'JJ'),
#   ('le', 'NN'),
#   ('proread', 'NN')],
#  [('nice', 'JJ'),
#   ('phone', 'NN'),
#   ('notification', 'NN'),
#   ('light', 'VBD'),
#   ('remot', 'NNS'),
#   ('missingread', 'NN')],
#  [('everything', 'NN'),
#   ('good', 'JJ'),
#   ('thismobile', 'NN'),
#   ('fhoneread', 'NN')],
#  [('superbread', 'NN')],
#  [('good', 'JJ'),
#   ('mobile', 'NN'),
#   ('display', 'NN'),
#   ('working', 'VBG'),
#   ('somethingthis', 'NN'),
#   ('mobile', 'JJ'),
#   ('charging', 'VBG'),
#   ('fast', 'RB'),
#   ('read', 'VB')],
#  [('asom', 'NN'), ('camera', 'NN'), ('loved', 'VBN'), ('read', 'NN')],
#  [('good', 'JJ'),
#   ('picture', 'NN'),
#   ('capture', 'NN'),
#   ('according', 'VBG'),
#   ('camera', 'NN'),
#   ('improvementread', 'NN')],
#  [('amazing', 'JJ'),
#   ('awesome', 'JJ'),
#   ('product', 'NN'),
#   ('camera', 'NN'),
#   ('wowread', 'NN')],
#  [('camera', 'NN'),
#   ('good', 'JJ'),
#   ('display', 'NN'),
#   ('horrible', 'JJ'),
#   ('thats', 'NNS'),
#   ('given', 'VBN'),
#   ('starread', 'VBP')],
#  [('awesome', 'JJ'),
#   ('camera', 'NN'),
#   ('screen', 'NN'),
#   ('quality', 'NN'),
#   ('superb', 'VBP'),
#   ('overall', 'JJ'),
#   ('best', 'RB'),
#   ('phone', 'NN'),
#   ('price', 'NN'),
#   ('rangeread', 'NN')],
#  [('within', 'IN'),
#   ('month', 'NN'),
#   ('product', 'NN'),
#   ('found', 'VBD'),
#   ('issue', 'NN'),
#   ('get', 'VB'),
#   ('scroll', 'JJ'),
#   ('opening', 'VBG'),
#   ('apps', 'JJ'),
#   ('function', 'NN'),
#   ('without', 'IN'),
#   ('usingread', 'JJ')],
#  [('best', 'JJS'), ('phone', 'NN'), ('superb', 'NN'), ('cameraread', 'NN')],
#  [('best', 'JJS'), ('itamread', 'NN')],
#  [('realme', 'NN'),
#   ('best', 'JJS'),
#   ('phone', 'NN'),
#   ('good', 'JJ'),
#   ('phoneread', 'NN')],
#  [('like', 'IN'), ('phoneread', 'NN')],
#  [('clean', 'JJ'), ('cemararead', 'NN')],
#  [('realme', 'NN'),
#   ('best', 'RBS'),
#   ('segment', 'NN'),
#   ('flipkart', 'JJ'),
#   ('exchange', 'NN'),
#   ('completely', 'RB'),
#   ('worst', 'VBD'),
#   ('one', 'CD'),
#   ('point', 'NN'),
#   ('screch', 'NN'),
#   ('accept', 'IN'),
#   ('really', 'RB'),
#   ('disappointed', 'JJ'),
#   ('exchangeread', 'NN')],
#  [('best', 'JJS'), ('performanceread', 'NN')],
#  [('nice', 'RB'),
#   ('mobile', 'JJ'),
#   ('superb', 'NN'),
#   ('camera', 'NN'),
#   ('qualityread', 'NN')],
#  [('goodread', 'NN')],
#  [('battery', 'NN'),
#   ('backup', 'NN'),
#   ('bestbeast', 'NN'),
#   ('performanceread', 'NN')],
#  [('value', 'NN'), ('moneyread', 'NN')],
#  [('screen', 'NN'), ('blinking', 'VBG'), ('issuesread', 'NN')],
#  [('realme', 'NN'),
#   ('best', 'JJS'),
#   ('phone', 'NN'),
#   ('generationi', 'NN'),
#   ('like', 'IN'),
#   ('read', 'NN')],
#  [('think', 'VB'),
#   ('realme', 'NN'),
#   ('smartphone', 'NN'),
#   ('nice', 'JJ'),
#   ('phone', 'NN'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('excellenti', 'VBP'),
#   ('liked', 'VBN'),
#   ('cameradisplay', 'NN'),
#   ('smoothly', 'RB'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('niceread', 'NN')],
#  [('nice', 'JJ'),
#   ('one', 'CD'),
#   ('really', 'RB'),
#   ('like', 'IN'),
#   ('itread', 'NN')],
#  [('osm', 'JJ'), ('product', 'NN'), ('read', 'NN')],
#  [('camera', 'NN'),
#   ('super', 'NN'),
#   ('image', 'NN'),
#   ('quality', 'NN'),
#   ('like', 'IN'),
#   ('dslr', 'NN'),
#   ('osm', 'FW'),
#   ('fantastic', 'JJ'),
#   ('phone', 'NN'),
#   ('thisread', 'NN')],
#  [('best', 'JJS'), ('smart', 'NN'), ('phone', 'NN'), ('kread', 'NN')],
#  [('nice', 'JJ'), ('productread', 'NN')],
#  [('must', 'MD'), ('buy', 'VB'), ('budget', 'NN'), ('read', 'NN')],
#  [('good', 'JJ'), ('greatfull', 'NN'), ('product', 'NN'), ('read', 'VB')],
#  [('front', 'JJ'),
#   ('camera', 'NN'),
#   ('filthy', 'JJ'),
#   ('quality', 'NN'),
#   ('picture', 'NN'),
#   ('bad', 'JJ'),
#   ('waste', 'NN'),
#   ('money', 'NN'),
#   ('dont', 'NN'),
#   ('buy', 'VBP'),
#   ('realme', 'NNS'),
#   ('read', 'VBP')],
#  [('realme', 'RB'),
#   ('good', 'JJ'),
#   ('phone', 'NN'),
#   ('camera', 'NN'),
#   ('superbfast', 'NN'),
#   ('chargingnot', 'NN'),
#   ('issuegood', 'NN'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('fully', 'RB'),
#   ('satisfied', 'VBN'),
#   ('phoneread', 'NN')],
#  [('good', 'JJ'), ('phone', 'NN'), ('andread', 'NN')],
#  [('good', 'JJ'),
#   ('performance', 'NN'),
#   ('sometimes', 'RB'),
#   ('get', 'VB'),
#   ('hanged', 'JJ'),
#   ('using', 'VBG'),
#   ('work', 'NN'),
#   ('well', 'RB'),
#   ('buy', 'VB'),
#   ('mobile', 'JJ'),
#   ('quite', 'RB'),
#   ('low', 'JJ'),
#   ('mobileread', 'NN')],
#  [('amazing', 'VBG'),
#   ('phone', 'NN'),
#   ('thanku', 'NN'),
#   ('flipkartread', 'NN')],
#  [('camera', 'NN'), ('bestread', 'NN')],
#  [('good', 'JJ'), ('phone', 'NN'), ('read', 'NN')],
#  [('aswm', 'NNS'), ('priceread', 'VBP')],
#  [('overall', 'JJ'),
#   ('performance', 'NN'),
#   ('functional', 'JJ'),
#   ('feature', 'NN'),
#   ('good', 'JJ'),
#   ('read', 'NN')],
#  [('screen', 'NN'), ('blinking', 'VBG'), ('issuesread', 'NN')],
#  [('worth', 'JJ'), ('money', 'NN'), ('good', 'JJ'), ('qualityread', 'NN')],
#  [('mind', 'NN'), ('blowing', 'VBG'), ('performanceread', 'NN')],
#  [('good', 'JJ'), ('quality', 'NN'), ('without', 'IN'), ('read', 'NN')],
#  [('awesome', 'JJ'), ('camera', 'NN'), ('read', 'NN')],
#  [('phone', 'NN'),
#   ('amazing', 'VBG'),
#   ('budgetcamera', 'NN'),
#   ('awesomeread', 'NN')],
#  [('goodread', 'NN')],
#  [('good', 'JJ'),
#   ('camera', 'NN'),
#   ('performance', 'NN'),
#   ('also', 'RB'),
#   ('good', 'JJ'),
#   ('read', 'NN')],
#  [('nice', 'JJ'), ('cameraread', 'NN')],
#  [('bad', 'JJ'),
#   ('product', 'NN'),
#   ('realme', 'NN'),
#   ('please', 'NN'),
#   ('read', 'VB'),
#   ('dont', 'JJ'),
#   ('buy', 'VB'),
#   ('product', 'NN'),
#   ('highly', 'RB'),
#   ('recommended', 'JJ'),
#   ('month', 'NN'),
#   ('using', 'VBG'),
#   ('face', 'VBP'),
#   ('many', 'JJ'),
#   ('problem', 'NN'),
#   ('phone', 'NN'),
#   ('phone', 'NN'),
#   ('call', 'NN'),
#   ('sensor', 'NN'),
#   ('working', 'VBG'),
#   ('properly', 'RB'),
#   ('im', 'VB'),
#   ('call', 'NN'),
#   ('phone', 'NN'),
#   ('screen', 'NN'),
#   ('calling', 'VBG'),
#   ('automatically', 'RB'),
#   ('screen', 'JJ'),
#   ('please', 'NN'),
#   ('fix', 'VB'),
#   ('phone', 'NN'),
#   ('call', 'NN'),
#   ('app', 'NN'),
#   ('bad', 'JJ'),
#   ('working', 'VBG'),
#   ('properlyplease', 'NN'),
#   ('remove', 'VB'),
#   ('app', 'IN'),
#   ('opening', 'VBG'),
#   ('apps', 'RP'),
#   ('clicking', 'VBG'),
#   ('home', 'NN'),
#   ('button', 'NN'),
#   ('screen', 'NN'),
#   ('hang', 'NN'),
#   ('stopped', 'VBD'),
#   ('whenread', 'NN')],
#  [('im', 'NN'),
#   ('facing', 'VBG'),
#   ('touch', 'JJ'),
#   ('issue', 'NN'),
#   ('like', 'IN'),
#   ('ghost', 'NN'),
#   ('touch', 'JJ'),
#   ('irresponsive', 'JJ'),
#   ('touch', 'NN'),
#   ('display', 'NN'),
#   ('flickering', 'VBG'),
#   ('issuei', 'NN'),
#   ('updated', 'VBD'),
#   ('software', 'NN'),
#   ('still', 'RB'),
#   ('im', 'VBZ'),
#   ('facing', 'VBG'),
#   ('problem', 'NN'),
#   ('pls', 'NN'),
#   ('think', 'VBP'),
#   ('going', 'VBG'),
#   ('buy', 'VB'),
#   ('realme', 'JJ'),
#   ('phone', 'NN'),
#   ('hope', 'NN'),
#   ('realme', 'NN'),
#   ('care', 'NN'),
#   ('customer', 'NN'),
#   ('resolve', 'NN'),
#   ('problem', 'NN'),
#   ('otherwise', 'RB'),
#   ('last', 'JJ'),
#   ('realme', 'NN'),
#   ('phoneread', 'NN')],
#  [('say', 'VB'), ('awesomeat', 'JJ'), ('price', 'NN'), ('specsread', 'NN')],
#  [('nice', 'JJ'),
#   ('phone', 'NN'),
#   ('take', 'VB'),
#   ('short', 'JJ'),
#   ('time', 'NN'),
#   ('delivery', 'NN'),
#   ('deliver', 'NN'),
#   ('within', 'IN'),
#   ('hourread', 'NN')],
#  [('great', 'JJ'), ('camera', 'NN'), ('qualityread', 'NN')],
#  [('overall', 'JJ'),
#   ('performance', 'NN'),
#   ('goodcamera', 'NN'),
#   ('hz', 'NN'),
#   ('display', 'NN'),
#   ('battery', 'NN'),
#   ('charging', 'VBG'),
#   ('take', 'VB'),
#   ('hour', 'NN'),
#   ('full', 'JJ'),
#   ('charge', 'NN'),
#   ('certainly', 'RB'),
#   ('u', 'JJ'),
#   ('feel', 'NN'),
#   ('differencein', 'JJ'),
#   ('price', 'NN'),
#   ('certainly', 'RB'),
#   ('awesomebut', 'VBZ'),
#   ('yar', 'JJ'),
#   ('ye', 'NN'),
#   ('call', 'NN'),
#   ('recording', 'VBG'),
#   ('krne', 'JJ'),
#   ('pr', 'NN'),
#   ('samne', 'NN'),
#   ('wale', 'NN'),
#   ('ko', 'NN'),
#   ('msg', 'NN'),
#   ('chla', 'NN'),
#   ('jata', 'NN'),
#   ('hye', 'NN'),
#   ('kya', 'NN'),
#   ('hread', 'NN')],
#  [('day', 'NN'),
#   ('used', 'VBD'),
#   ('giving', 'VBG'),
#   ('review', 'NN'),
#   ('realme', 'NN'),
#   ('want', 'VBP'),
#   ('inform', 'NN'),
#   ('review', 'NN'),
#   ('viewer', 'NN'),
#   ('im', 'NN'),
#   ('pubg', 'NN'),
#   ('high', 'JJ'),
#   ('gaming', 'NN'),
#   ('player', 'NN'),
#   ('photography', 'NN'),
#   ('realme', 'NN'),
#   ('st', 'NN'),
#   ('camera', 'NN'),
#   ('good', 'JJ'),
#   ('expectednd', 'NN'),
#   ('heating', 'VBG'),
#   ('issue', 'NN'),
#   ('hang', 'NN'),
#   ('lag', 'NN'),
#   ('perfect', 'JJ'),
#   ('rd', 'JJ'),
#   ('picture', 'NN'),
#   ('zoom', 'NN'),
#   ('clearity', 'NN'),
#   ('good', 'JJ'),
#   ('important', 'JJ'),
#   ('battery', 'NN'),
#   ('full', 'JJ'),
#   ('charge', 'NN'),
#   ('hour', 'NN'),
#   ('game', 'NN'),
#   ('play', 'NN'),
#   ('brightness', 'RB'),
#   ('hour', 'NN'),
#   ('youtube', 'NN'),
#   ('brightness', 'NN'),
#   ('dont', 'NN'),
#   ('use', 'IN'),
#   ('hour', 'NN'),
#   ('hour', 'NN'),
#   ('still', 'RB'),
#   ('peopleread', 'VB')],
#  [('first', 'JJ'),
#   ('time', 'NN'),
#   ('used', 'VBN'),
#   ('android', 'NN'),
#   ('mobile', 'JJ'),
#   ('life', 'NN'),
#   ('realmeread', 'NN')],
#  [('really', 'RB'), ('greatread', 'JJ')],
#  [('classy', 'JJ'),
#   ('turbulent', 'NN'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('niceread', 'NN')],
#  [('network', 'NN'), ('issueread', 'NN')],
#  [('nice', 'RB'),
#   ('mobile', 'RB'),
#   ('amoled', 'VBN'),
#   ('display', 'NN'),
#   ('disappointedread', 'NN')],
#  [('nice', 'JJ'), ('phone', 'NN'), ('good', 'JJ'), ('performaneread', 'NN')],
#  [('realme', 'NN'),
#   ('best', 'JJS'),
#   ('mobile', 'NN'),
#   ('phone', 'NN'),
#   ('battery', 'NN'),
#   ('fast', 'RB'),
#   ('drainread', 'JJ')],
#  [('superb', 'NN'), ('cameraread', 'NN')],
#  [('nice', 'RB'),
#   ('mobile', 'JJ'),
#   ('love', 'VBP'),
#   ('flipchart', 'NN'),
#   ('read', 'NN')],
#  [('nice', 'JJ'), ('phoneread', 'NN')],
#  [('best', 'JJS'),
#   ('product', 'NN'),
#   ('crash', 'NN'),
#   ('even', 'RB'),
#   ('falling', 'VBG'),
#   ('height', 'VBN'),
#   ('thanksread', 'NN')],
#  [('overall', 'JJ'), ('gud', 'NN'), ('productread', 'NN')],
#  [('wow', 'NN'), ('camera', 'NN'), ('broworthread', 'NN')],
#  [('amazingread', 'NN')],
#  [('value', 'NN'), ('moneyread', 'NN')],
#  [('screen', 'NN'),
#   ('flikering', 'VBG'),
#   ('problem', 'NN'),
#   ('solved', 'VBD'),
#   ('updation', 'JJ'),
#   ('kachada', 'NNP'),
#   ('hai', 'NN'),
#   ('bhaiwrist', 'NN'),
#   ('phone', 'NN'),
#   ('everread', 'NN')],
#  [('display', 'NN'),
#   ('working', 'VBG'),
#   ('automaticallydisplay', 'NN'),
#   ('issueread', 'NN')],
#  [('best', 'JJS'), ('valueread', 'NN')],
#  [('good', 'JJ'), ('mobileread', 'NN')],
#  [('dont', 'NNS'),
#   ('need', 'VBP'),
#   ('dslr', 'JJ'),
#   ('awesome', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('recommendread', 'NN')],
#  [('goodread', 'NN')],
#  [('awesome', 'JJ'), ('phone', 'NN'), ('loved', 'VBD'), ('itread', 'NN')],
#  [('problem', 'NN'),
#   ('software', 'NN'),
#   ('started', 'VBD'),
#   ('day', 'NN'),
#   ('return', 'NN'),
#   ('policy', 'NN'),
#   ('day', 'NN'),
#   ('screen', 'JJ'),
#   ('start', 'NN'),
#   ('scrolling', 'VBG'),
#   ('automatically', 'RB'),
#   ('sometimes', 'RB'),
#   ('apps', 'JJ'),
#   ('start', 'NN'),
#   ('closing', 'VBG'),
#   ('opening', 'VBG'),
#   ('automatically', 'RB'),
#   ('took', 'VBD'),
#   ('customer', 'NN'),
#   ('care', 'NN'),
#   ('still', 'RB'),
#   ('working', 'VBG'),
#   ('properly', 'RB'),
#   ('screen', 'NN'),
#   ('still', 'RB'),
#   ('start', 'VB'),
#   ('scrolling', 'VBG'),
#   ('automatically', 'RB'),
#   ('several', 'JJ'),
#   ('time', 'NN'),
#   ('bad', 'JJ'),
#   ('experience', 'NN'),
#   ('regretting', 'VBG'),
#   ('terriblyread', 'NN')],
#  [('realme', 'NN'),
#   ('nice', 'JJ'),
#   ('phone', 'NN'),
#   ('camera', 'NN'),
#   ('display', 'NN'),
#   ('best', 'JJS'),
#   ('performance', 'NN'),
#   ('read', 'NN')],
#  [('tooooo', 'NNS'), ('goodread', 'VBP')],
#  [('osm', 'RB'), ('mobile', 'JJ'), ('price', 'NN'), ('rangeread', 'NN')],
#  [('bestread', 'NN')],
#  [('awesome', 'JJ'), ('androidbest', 'JJS'), ('rangeread', 'NN')],
#  [('amazing', 'VBG'),
#   ('overall', 'JJ'),
#   ('experiencehaving', 'VBG'),
#   ('heating', 'NN'),
#   ('issue', 'NN'),
#   ('gaming', 'VBG'),
#   ('talking', 'VBG'),
#   ('ui', 'JJ'),
#   ('light', 'JJ'),
#   ('clean', 'JJ'),
#   ('stock', 'NN'),
#   ('android', 'NN'),
#   ('apps', 'NN'),
#   ('like', 'IN'),
#   ('messaging', 'VBG'),
#   ('found', 'JJ'),
#   ('way', 'NN'),
# ...
#  [('goodread', 'NN')],
#  [('india', 'NN'),
#   ('bestest', 'JJS'),
#   ('mobile', 'JJ'),
#   ('smart', 'JJ'),
#   ('phoneread', 'NN')],
#  [('goodread', 'NN')],
#  [('defective', 'JJ'),
#   ('product', 'NN'),
#   ('battery', 'NN'),
#   ('performance', 'NN'),
#   ('badread', 'NN')],
#  [('thank', 'JJ'), ('flipkart', 'RB'), ('good', 'JJ'), ('mobileread', 'NN')],
#  [('waste', 'NN'), ('moneyread', 'NN')],
#  [('niceread', 'NN')],
#  [('worthread', 'NN')],
#  [('nice', 'JJ'), ('phone', 'NN'), ('price', 'NN'), ('decreaseread', 'NN')],
#  [('nice', 'JJ'), ('camera', 'NN'), ('read', 'NN')],
#  [('frant', 'JJ'), ('light', 'NN'), ('chitterread', 'NN')],
#  [('goodread', 'NN')],
#  [('goodread', 'NN')],
#  [('nice', 'JJ'), ('phoneread', 'NN')],
#  [('good', 'JJ'), ('mobile', 'NN'), ('cemera', 'NN'), ('bestread', 'NN')],
#  [('good', 'JJ'), ('productread', 'NN')],
#  [('awsomeread', 'NN')],
#  [('nice', 'JJ'), ('product', 'NN'), ('good', 'JJ'), ('qualityread', 'NN')],
#  [('best', 'JJS'), ('cemararead', 'NN')],
#  [('superbread', 'NN')],
#  [('bestread', 'NN')],
#  [('great', 'JJ'),
#   ('product', 'NN'),
#   ('heavy', 'JJ'),
#   ('quality', 'NN'),
#   ('product', 'NN'),
#   ('design', 'NN'),
#   ('also', 'RB'),
#   ('cool', 'JJ'),
#   ('smarty', 'NN'),
#   ('best', 'JJS'),
#   ('product', 'NN'),
#   ('would', 'MD'),
#   ('suggest', 'VB'),
#   ('everyone', 'NN'),
#   ('model', 'NN'),
#   ('good', 'JJ'),
#   ('efficient', 'JJ'),
#   ('product', 'NN'),
#   ('rather', 'RB'),
#   ('model', 'JJ'),
#   ('realmeread', 'NN')],
#  [('best', 'JJS'), ('mobile', 'NN'), ('read', 'NN')],
#  [('nice', 'JJ'), ('phoneread', 'NN')],
#  [('good', 'JJ'),
#   ('camera', 'NN'),
#   ('set', 'VBN'),
#   ('good', 'JJ'),
#   ('gaming', 'NN'),
#   ('processorand', 'NN'),
#   ('good', 'JJ'),
#   ('charging', 'VBG'),
#   ('speed', 'NN'),
#   ('take', 'VB'),
#   ('min', 'NN'),
#   ('fully', 'RB'),
#   ('chargedread', 'JJ')],
#  [('nice', 'JJ'), ('productread', 'NN')],
#  [('wowread', 'NN')],
#  [('love', 'VB'), ('phone', 'NN'), ('read', 'NN')],
#  [('goodread', 'NN')],
#  [('waste', 'NN'),
#   ('money', 'NN'),
#   ('hang', 'NN'),
#   ('problem', 'NN'),
#   ('good', 'JJ'),
#   ('performanceread', 'NN')],
#  [('love', 'NN'), ('productread', 'NN')],
#  [('awesome', 'JJ'), ('product', 'NN'), ('good', 'JJ'), ('qualityread', 'NN')],
#  [('best', 'JJS'),
#   ('smart', 'JJ'),
#   ('phonebest', 'NN'),
#   ('camera', 'NN'),
#   ('best', 'JJS'),
#   ('display', 'NN'),
#   ('best', 'RBS'),
#   ('battery', 'NN'),
#   ('lifeworth', 'NN'),
#   ('itread', 'NN')],
#  [('good', 'JJ'), ('read', 'NN')],
#  [('great', 'JJ'), ('product', 'NN'), ('hope', 'NN'), ('wontread', 'NN')],
#  [('best', 'JJS'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('among', 'IN'),
#   ('competitor', 'NN'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('cool', 'JJ'),
#   ('issue', 'NN'),
#   ('till', 'NN'),
#   ('nowonly', 'RB'),
#   ('con', 'JJ'),
#   ('weighs', 'NNS'),
#   ('read', 'VBP')],
#  [('nice', 'JJ'),
#   ('phone', 'NN'),
#   ('good', 'JJ'),
#   ('gaming', 'NN'),
#   ('multitaskingread', 'NN')],
#  [('niceread', 'NN')],
#  [('nice', 'JJ'), ('photogrsphyread', 'NN')],
#  [('nice', 'JJ'),
#   ('size', 'NN'),
#   ('slightly', 'RB'),
#   ('smaller', 'JJR'),
#   ('compare', 'NN'),
#   ('poco', 'NN'),
#   ('proread', 'NN')],
#  [('nice', 'JJ'), ('mobileread', 'NN')],
#  [('god', 'NNS'), ('productread', 'VBP')],
#  [('mobile', 'JJ'),
#   ('hang', 'NN'),
#   ('screen', 'JJ'),
#   ('black', 'JJ'),
#   ('useread', 'NN')],
#  [('nice', 'JJ'), ('product', 'NN'), ('read', 'NN')],
#  [('niceread', 'NN')],
#  [('expected', 'VBN'), ('read', 'NN')],
#  [('disgustingvery', 'NN'),
#   ('badafter', 'NN'),
#   ('spending', 'NN'),
#   ('notification', 'NN'),
#   ('light', 'VBD'),
#   ('call', 'JJ'),
#   ('recording', 'NN'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('poor', 'JJ'),
#   ('display', 'NN'),
#   ('bad', 'JJ'),
#   ('heating', 'JJ'),
#   ('issue', 'NN'),
#   ('product', 'NN'),
#   ('designed', 'VBN'),
#   ('way', 'NN'),
#   ('detereiorated', 'VBN'),
#   ('within', 'IN'),
#   ('year', 'NN'),
#   ('go', 'VBP'),
#   ('brand', 'NN'),
#   ('xiaomivivooppopoco', 'NN'),
#   ('etcread', 'NN')],
#  [('goodread', 'NN')],
#  [('gyroscope', 'NN'), ('working', 'VBG'), ('shotread', 'NN')],
#  [('nice', 'JJ'), ('phoneread', 'NN')],
#  [('hang', 'NN'), ('sometimes', 'RB'), ('rest', 'VBP'), ('goodread', 'NN')],
#  [('good', 'JJ'),
#   ('service', 'NN'),
#   ('good', 'JJ'),
#   ('product', 'NN'),
#   ('flipkartread', 'NN')],
#  [('osmread', 'NN')],
#  [('goodread', 'NN')],
#  [('best', 'RB'),
#   ('phone', 'NN'),
#   ('best', 'JJS'),
#   ('camera', 'NN'),
#   ('nd', 'NN'),
#   ('bettery', 'NN'),
#   ('backupsread', 'NN')],
#  [('niceread', 'NN')],
#  [('camera', 'NN'),
#   ('good', 'JJ'),
#   ('performance', 'NN'),
#   ('also', 'RB'),
#   ('good', 'JJ'),
#   ('battery', 'NN'),
#   ('drain', 'NN'),
#   ('overall', 'JJ'),
#   ('phone', 'NN'),
#   ('goodread', 'NN')],
#  [('great', 'JJ'), ('productread', 'NN')],
#  [('th', 'JJ'),
#   ('delivery', 'NN'),
#   ('guy', 'NN'),
#   ('friendlyhats', 'NNS'),
#   ('himread', 'VBP')],
#  [('good', 'JJ'), ('bestread', 'NN')],
#  [('battery', 'NN'),
#   ('backup', 'NN'),
#   ('superbcamera', 'NN'),
#   ('quality', 'NN'),
#   ('excellent', 'JJ'),
#   ('charging', 'VBG'),
#   ('good', 'JJ'),
#   ('love', 'NN'),
#   ('realme', 'NN'),
#   ('mobile', 'NN'),
#   ('read', 'NN')],
#  [('badread', 'NN')],
#  [('sweet', 'JJ'), ('beautiful', 'JJ'), ('nice', 'JJ'), ('read', 'NN')],
#  [('time', 'NN'),
#   ('phone', 'NN'),
#   ('getting', 'VBG'),
#   ('heat', 'NN'),
#   ('phone', 'NN'),
#   ('ok', 'JJ'),
#   ('badread', 'NN')],
#  [('nice', 'JJ'), ('phone', 'NN'), ('value', 'NN'), ('moneyread', 'NN')],
#  [('excellentread', 'NN')],
#  [('satisfied', 'JJ'),
#   ('product', 'NN'),
#   ('month', 'NN'),
#   ('issue', 'NN'),
#   ('thank', 'VBD'),
#   ('flipkartread', 'JJ')],
#  [('amazing', 'VBG'),
#   ('phone', 'NN'),
#   ('battery', 'NN'),
#   ('backupread', 'NN')],
#  [('goodread', 'NN')],
#  [('well', 'RB'),
#   ('old', 'JJ'),
#   ('phonebest', 'NN'),
#   ('rate', 'NN'),
#   ('allread', 'NN')],
#  [('go', 'VB'), ('read', 'NN')],
#  [('give', 'VB'),
#   ('star', 'NN'),
#   ('realme', 'NN'),
#   ('good', 'JJ'),
#   ('design', 'NN'),
#   ('value', 'NN'),
#   ('money', 'NN'),
#   ('like', 'IN'),
#   ('productread', 'NN')],
#  [('good', 'JJ'), ('phoneread', 'NN')],
#  [('month', 'NN'),
#   ('using', 'VBG'),
#   ('mobile', 'JJ'),
#   ('superb', 'NN'),
#   ('mobile', 'JJ'),
#   ('heavy', 'JJ'),
#   ('user', 'NN'),
#   ('play', 'NN'),
#   ('pubg', 'NN'),
#   ('lot', 'NN'),
#   ('also', 'RB'),
#   ('online', 'JJ'),
#   ('class', 'NN'),
#   ('storage', 'NN'),
#   ('also', 'RB'),
#   ('fill', 'JJ'),
#   ('gb', 'NNS'),
#   ('also', 'RB'),
#   ('mobile', 'VBP'),
#   ('working', 'VBG'),
#   ('smoothly', 'RB'),
#   ('buy', 'VB'),
#   ('u', 'JJ'),
#   ('heavy', 'JJ'),
#   ('driver', 'NN'),
#   ('superb', 'NN'),
#   ('mobile', 'JJ'),
#   ('buy', 'NN'),
#   ('without', 'IN'),
#   ('hesitation', 'NN'),
#   ('read', 'NN')],
#  [('amazing', 'JJ'),
#   ('transparent', 'NN'),
#   ('cover', 'NN'),
#   ('alsoread', 'NN')],
#  [('good', 'JJ'),
#   ('nice', 'JJ'),
#   ('product', 'NN'),
#   ('much', 'JJ'),
#   ('fast', 'NN'),
#   ('deliveryread', 'NN')],
#  [('best', 'JJS'), ('phoneread', 'NN')],
#  [('goodread', 'NN')],
#  [('excellent', 'JJ'),
#   ('experience', 'NN'),
#   ('phone', 'NN'),
#   ('till', 'NN'),
#   ('nowread', 'NN')],
#  [('goodread', 'NN')],
#  [('much', 'JJ'), ('qualitativeread', 'NN')],
#  [('superread', 'NN')],
#  [('nice', 'RB'), ('mobile', 'JJ'), ('value', 'NN'), ('moneyread', 'NN')],
#  [('niceread', 'NN')],
#  [('good', 'JJ'), ('product', 'NN'), ('refund', 'NN'), ('okread', 'NN')],
#  [('faced', 'VBN'),
#   ('heating', 'VBG'),
#   ('issue', 'NN'),
#   ('initially', 'RB'),
#   ('later', 'RB'),
#   ('sorted', 'VBN'),
#   ('awsm', 'RP'),
#   ('phne', 'JJ'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('impressed', 'VBD'),
#   ('realmeread', 'NN')],
#  [('good', 'JJ'),
#   ('pricerangebut', 'NN'),
#   ('still', 'RB'),
#   ('satisfiedit', 'VBZ'),
#   ('betterbattery', 'NN'),
#   ('backup', 'NN'),
#   ('awesomeread', 'NN')],
#  [('best', 'JJS'),
#   ('market', 'NN'),
#   ('overall', 'JJ'),
#   ('look', 'NN'),
#   ('osm', 'JJ'),
#   ('midrange', 'NN'),
#   ('price', 'NN'),
#   ('realme', 'NN'),
#   ('loverread', 'NN')],
#  [('goodread', 'NN')],
#  [('goodread', 'NN')],
#  [('niceread', 'NN')],
#  [('value', 'NN'), ('moneyread', 'NN')],
#  [('best', 'JJS'), ('cameraread', 'NN')],
#  [('mindblowingread', 'NN')],
#  [('stable', 'JJ'), ('updateread', 'NN')],
#  [('camera', 'NN'), ('superread', 'NN')],
#  [('supper', 'NN'), ('goodread', 'NN')],
#  [('goodread', 'NN')],
#  [('wonderful', 'NN'), ('mobile', 'NN'), ('go', 'VBP'), ('itread', 'NN')],
#  [('v', 'NNS'), ('goodread', 'VBP')],
#  [('good', 'JJ'),
#   ('deal', 'NN'),
#   ('medium', 'NN'),
#   ('price', 'NN'),
#   ('awesome', 'JJ'),
#   ('love', 'NN'),
#   ('itread', 'NN')],
#  [('timeread', 'NN')],
#  [('nice', 'JJ'), ('mobileread', 'NN')],
#  [('lagging', 'JJ'),
#   ('time', 'NN'),
#   ('even', 'RB'),
#   ('powerful', 'JJ'),
#   ('processorread', 'NN')],
#  [('best', 'RB'), ('smartphone', 'NN'), ('price', 'NN'), ('rangeread', 'NN')],
#  [('niceread', 'NN')],
#  [('love', 'NN'), ('mobile', 'JJ'), ('feature', 'NN'), ('goodread', 'NN')],
#  [('goodread', 'NN')],
#  [('nice', 'JJ'), ('phone', 'NN'), ('price', 'NN'), ('segmentread', 'NN')],
#  [('superread', 'NN')],
#  [('bad', 'JJ'),
#   ('product', 'NN'),
#   ('charging', 'VBG'),
#   ('issue', 'NN'),
#   ('damege', 'NN'),
#   ('charging', 'VBG'),
#   ('boxread', 'NN')],
#  [('want', 'JJ'),
#   ('auto', 'NN'),
#   ('call', 'NN'),
#   ('recorder', 'NN'),
#   ('mobileread', 'NN')],
#  [('awesome', 'JJ'), ('read', 'NN')],
#  [('best', 'RB'), ('smartphone', 'NN'), ('price', 'NN'), ('rangeread', 'NN')],
#  [('excellent', 'JJ'), ('read', 'NN')],
#  [('full', 'JJ'),
#   ('satisfy', 'NN'),
#   ('mobile', 'IN'),
#   ('fast', 'JJ'),
#   ('camera', 'NN'),
#   ('amazing', 'VBG'),
#   ('spacially', 'RB'),
#   ('use', 'VB'),
#   ('night', 'NN'),
#   ('mode', 'NNS'),
#   ('take', 'VBP'),
#   ('minbattery', 'NN'),
#   ('backup', 'NN'),
#   ('goodread', 'NN')],
#  [('best', 'JJS'), ('productsread', 'NN')],
#  [('goodread', 'NN')],
#  [('screen', 'NN'),
#   ('initially', 'RB'),
#   ('flickering', 'VBG'),
#   ('update', 'JJ'),
#   ('got', 'VBD'),
#   ('resolved', 'VBN'),
#   ('however', 'RB'),
#   ('low', 'JJ'),
#   ('brightness', 'NN'),
#   ('phone', 'NN'),
#   ('function', 'NN'),
#   ('slow', 'JJ'),
#   ('otherwise', 'RB'),
#   ('amazing', 'VBG'),
#   ('phoneread', 'NN')],
#  [('excellent', 'JJ'),
#   ('dispay', 'NN'),
#   ('good', 'JJ'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('performance', 'NN'),
#   ('nice', 'JJ'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('badread', 'NN')],
#  [('nice', 'JJ'),
#   ('product', 'NN'),
#   ('yaar', 'NN'),
#   ('better', 'RBR'),
#   ('performance', 'NN'),
#   ('battery', 'NN'),
#   ('back', 'RB'),
#   ('also', 'RB'),
#   ('better', 'RBR'),
#   ('read', 'VB')],
#  [('goodread', 'NN')],
#  [('excellent', 'JJ'), ('mobileread', 'NN')],
#  [('good', 'JJ'), ('budget', 'NN'), ('segment', 'NN'), ('phoneread', 'NN')],
#  [('looking', 'VBG'), ('good', 'JJ'), ('read', 'NN')],
#  [('amazing', 'VBG'),
#   ('mobile', 'NN'),
#   ('phone', 'NN'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('much', 'JJ'),
#   ('nicerread', 'NN')],
#  [('goodread', 'NN')],
#  [('amazingrecommend', 'NN'), ('buyread', 'NN')],
#  [('nice', 'RB'), ('mobile', 'JJ'), ('best', 'JJS'), ('priceread', 'NN')],
#  [('seriously', 'RB'), ('amazingread', 'JJ')],
#  [('good', 'JJ'), ('performanceread', 'NN')],
#  [('value', 'NN'), ('moneyread', 'NN')],
#  [('good', 'JJ'), ('phoneread', 'NN')],
#  [('nice', 'JJ'),
#   ('smart', 'JJ'),
#   ('phone', 'NN'),
#   ('dont', 'NN'),
#   ('aspect', 'NN'),
#   ('budgetgood', 'NN'),
#   ('smooth', 'NNS'),
#   ('parfomnsread', 'VBP')],
#  [('awesome', 'JJ'),
#   ('phone', 'NN'),
#   ('got', 'VBD'),
#   ('rupee', 'JJ'),
#   ('excellent', 'JJ'),
#   ('love', 'NN'),
#   ('realmeread', 'NN')],
#  [('badread', 'NN')],
#  [('niceread', 'NN')],
#  [('nice', 'JJ'), ('phoneread', 'NN')],
#  [('worth', 'JJ'),
#   ('gaming', 'VBG'),
#   ('performance', 'NN'),
#   ('goodi', 'NN'),
#   ('likely', 'RB'),
#   ('one', 'CD'),
#   ('k', 'NN'),
#   ('worthread', 'NN')],
#  [('best', 'JJS'), ('mobile', 'NN'), ('phoneread', 'NN')],
#  [('worth', 'JJ'), ('moneycameraread', 'NN')],
#  [('budget', 'NN'),
#   ('phone', 'NN'),
#   ('really', 'RB'),
#   ('like', 'IN'),
#   ('thisread', 'NN')],
#  [('proximity', 'NN'),
#   ('sensor', 'NN'),
#   ('worst', 'WP'),
#   ('phone', 'NN'),
#   ('sometimes', 'RB'),
#   ('work', 'NN'),
#   ('time', 'NN'),
#   ('didnt', 'JJ'),
#   ('work', 'NN'),
#   ('allread', 'NN')],
#  [('good', 'JJ'), ('feeling', 'NN'), ('better', 'RBR'), ('read', 'NN')],
#  [('nice', 'JJ'), ('productread', 'NN')],
#  [('value', 'NN'),
#   ('money', 'NN'),
#   ('using', 'VBG'),
#   ('since', 'IN'),
#   ('week', 'NN'),
#   ('complaint', 'NN'),
#   ('good', 'JJ'),
#   ('productread', 'NN')],
#  [('niceread', 'NN')],
#  [('good', 'JJ'),
#   ('phone', 'NN'),
#   ('segment', 'NN'),
#   ('good', 'JJ'),
#   ('response', 'NN'),
#   ('flipkart', 'NN'),
#   ('deliveryread', 'NN')],
#  [('nice', 'JJ'),
#   ('mobile', 'JJ'),
#   ('performance', 'NN'),
#   ('mind', 'NN'),
#   ('blowing', 'VBG'),
#   ('battery', 'NN'),
#   ('enough', 'JJ'),
#   ('day', 'NN'),
#   ('u', 'JJ'),
#   ('r', 'NN'),
#   ('moderate', 'JJ'),
#   ('userread', 'NN')],
#  [('loved', 'VBN'),
#   ('phone', 'NN'),
#   ('nice', 'JJ'),
#   ('performance', 'NN'),
#   ('aasepctsread', 'NN')],
#  [('goodread', 'NN')],
#  [('phone', 'NN'), ('amazingread', 'NN')],
#  [('nice', 'JJ'),
#   ('mobilevalue', 'NN'),
#   ('moneygood', 'NN'),
#   ('looking', 'VBG'),
#   ('nice', 'JJ'),
#   ('performance', 'NN'),
#   ('nice', 'JJ'),
#   ('camerabattery', 'NN'),
#   ('performance', 'NN'),
#   ('also', 'RB'),
#   ('nicefast', 'RB'),
#   ('charging', 'VBG'),
#   ('availableread', 'NN')],
#  [('everything', 'NN'), ('goodread', 'NN')],
#  [('awsm', 'NNS'), ('phoneread', 'VBP')],
#  [('niceread', 'NN')],
#  [('ya', 'RB'),
#   ('good', 'JJ'),
#   ('phone', 'NN'),
#   ('realme', 'NN'),
#   ('fix', 'NN'),
#   ('bug', 'VBD'),
#   ('touch', 'JJ'),
#   ('response', 'NN'),
#   ('camera', 'NN'),
#   ('update', 'JJ'),
#   ('otherwise', 'RB'),
#   ('gaming', 'VBG'),
#   ('ke', 'NN'),
#   ('liye', 'NN'),
#   ('lallantopread', 'NN')],
#  [('niceread', 'NN')],
#  [('worst', 'RB'),
#   ('mobile', 'JJ'),
#   ('hanging', 'VBG'),
#   ('problemread', 'NN')],
#  [('goodread', 'NN')],
#  [('good', 'JJ'), ('font', 'NN'), ('camera', 'NN'), ('problemread', 'NN')],
#  [('touch', 'JJ'),
#   ('screen', 'NN'),
#   ('stop', 'NN'),
#   ('working', 'VBG'),
#   ('properlyread', 'NN')],
#  [('worst', 'RB'),
#   ('phone', 'NN'),
#   ('purchased', 'VBD'),
#   ('automatically', 'RB'),
#   ('valume', 'JJ'),
#   ('decreasing', 'VBG'),
#   ('listening', 'VBG'),
#   ('music', 'NN'),
#   ('sometimes', 'RB'),
#   ('fingerprint', 'JJ'),
#   ('workingread', 'NN')],
#  [('niceread', 'NN')],
#  [('badread', 'NN')],
#  [('nice', 'JJ'), ('phoneread', 'NN')],
#  [('hello', 'NN'),
#   ('guy', 'NN'),
#   ('review', 'NN'),
#   ('helpfull', 'JJ'),
#   ('purchase', 'NN'),
#   ('realme', 'NN'),
#   ('battery', 'NN'),
#   ('charging', 'VBG'),
#   ('performence', 'NN'),
#   ('look', 'NN'),
#   ('camera', 'NN'),
#   ('network', 'NN'),
#   ('quality', 'NN'),
#   ('display', 'NN'),
#   ('brightness', 'NN'),
#   ('thinness', 'NN'),
#   ('heating', 'VBG'),
#   ('issueread', 'NN')],
#  [('fabulous', 'JJ'),
#   ('beauty', 'NN'),
#   ('purchased', 'VBD'),
#   ('flipkart', 'JJ'),
#   ('bro', 'NN'),
#   ('want', 'VBP'),
#   ('talk', 'NN'),
#   ('something', 'NN'),
#   ('mentioned', 'VBD'),
#   ('hz', 'JJ'),
#   ('display', 'NN'),
#   ('good', 'JJ'),
#   ('feature', 'NN'),
#   ('improvedhey', 'NN'),
#   ('guy', 'VBP'),
#   ('phone', 'NN'),
#   ('heat', 'NN'),
#   ('much', 'JJ'),
#   ('playing', 'NN'),
#   ('pubg', 'NN'),
#   ('inside', 'IN'),
#   ('trust', 'NN'),
#   ('gaming', 'VBG'),
#   ('experience', 'NN'),
#   ('good', 'JJ'),
#   ('good', 'JJ'),
#   ('gpu', 'NN'),
#   ('g', 'NN'),
#   ('known', 'VBN'),
#   ('great', 'JJ'),
#   ('clock', 'NN'),
#   ('speed', 'NN'),
#   ('going', 'VBG'),
#   ('much', 'JJ'),
#   ('technical', 'JJ'),
#   ('want', 'NN'),
#   ('go', 'VBP'),
#   ('remember', 'VB'),
#   ('one', 'CD'),
#   ('thing', 'NN'),
#   ('phone', 'NN'),
#   ('heat', 'NN'),
#   ('muchread', 'NN')],
#  [('hopeless', 'JJ'),
#   ('mobail', 'NN'),
#   ('hangging', 'VBG'),
#   ('overheating', 'VBG'),
#   ('issue', 'NN'),
#   ('flipkart', 'RB'),
#   ('refused', 'VBD'),
#   ('replace', 'VB'),
#   ('returnread', 'NN')],
#  [('goodread', 'NN')],
#  [('night', 'NN'), ('mode', 'NN'), ('camera', 'NN'), ('awesomeread', 'NN')],
#  [('im', 'NNS'), ('happyread', 'VBP')],
#  [('niceread', 'NN')],
#  [('great', 'JJ'), ('cameraread', 'NN')],
#  [('goodread', 'NN')],
#  [('niceread', 'NN')],
#  [('goodread', 'NN')],
#  [('awesomeread', 'NN')],
#  [('happyread', 'NN')],
#  [('nice', 'JJ'), ('phoneread', 'NN')],
#  [('happy', 'JJ'), ('buy', 'NN'), ('itread', 'NN')]]

# %%
Adjective = []
Adverb = []
CordinatingConjunction = []
SubordinatingConjuction = []
Interjection = []
Noun = []
Verb = []
PersonalPronoun = []
predeterminer = []
Determiner = []

# %%
for value in pos:
  AdjectiveCount = 0
  AdverbCount = 0
  CordinatingConjunctionCount = 0
  SubordinatingConjuctionCount = 0
  InterjectionCount = 0
  NounCount = 0
  VerbCount = 0
  PersonalPronounCount = 0
  predeterminerCount = 0
  DeterminerCount = 0
  for word,tag in value:
    if tag == 'JJ':
      AdjectiveCount = AdjectiveCount + 1
    elif tag == 'RB':
      AdverbCount = AdverbCount + 1
    elif tag == 'CC':
      CordinatingConjunctionCount = CordinatingConjunctionCount + 1
    elif tag == 'UH':
      InterjectionCount = InterjectionCount + 1
    elif tag == 'NN':
      NounCount = NounCount + 1
    elif tag == 'VR':
      VerbCount = VerbCount + 1
    elif tag == 'PRP':
      PersonalPronounCount = PersonalPronounCount + 1
    elif tag == 'PDT':
      predeterminerCount = predeterminerCount + 1
    elif tag == 'DT':
      DeterminerCount = DeterminerCount + 1
    elif tag == 'IN':
      SubordinatingConjuctionCount = SubordinatingConjuctionCount + 1
  Adjective.append(AdjectiveCount)
  Adverb.append(AdverbCount)
  CordinatingConjunction.append(CordinatingConjunctionCount)
  Interjection.append(InterjectionCount)
  Noun.append(NounCount)
  Verb.append(VerbCount)
  PersonalPronoun.append(PersonalPronounCount)
  predeterminer.append(predeterminerCount)
  Determiner.append(DeterminerCount)
  SubordinatingConjuction.append(SubordinatingConjuctionCount)

# %%
df['Number of Adjectives'] = Adjective
df['Number of Adverbs'] = Adverb
df['Number of Cordinating Conjunctions'] = CordinatingConjunction
df['Number of Interjections'] = Interjection
df['Number of Nouns'] = Noun
df['Number of Verbs'] = Verb
df['Number of Personal Pronouns'] = PersonalPronoun
df['Number of Predeterminers'] = predeterminer
df['Number of Determiners'] = Determiner
df['Number of Subordinating Conjuctions'] = SubordinatingConjuction
df
# Out:
#          Glimpse of Review  ... Number of Subordinating Conjuctions
# 0     Good quality product  ...                                   0
# 1                Must buy!  ...                                   0
# 2          Worth the money  ...                                   0
# 3                Wonderful  ...                                   4
# 4    Mind-blowing purchase  ...                                   1
# ..                     ...  ...                                 ...
# 505              Excellent  ...                                   0
# 506         Classy product  ...                                   0
# 507              Must buy!  ...                                   0
# 508              Just wow!  ...                                   0
# 509      Terrific purchase  ...                                   0
#
# [510 rows x 13 columns]

# %% [markdown]
# **Linguistic features**
# **Number of right-branching nodes **

# %%
pip install -U spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (3.0.3)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.7.0)
# Requirement already satisfied: pathy in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.0)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.3.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (54.1.0)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.7.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.7.4.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (20.9)
# Requirement already satisfied: thinc<8.1.0,>=8.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (8.0.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.41.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.19.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->spacy) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy) (1.1.1)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pathy->spacy) (3.0.0)

# %%
nlp = spacy.load("en_core_web_sm")
RightBranchingNodes = []
for sentence in df['After Preprocessing']:
  doc = nlp(sentence)
  try:
    RightBranchingNodes.append(doc[0].n_rights)
  except:
    RightBranchingNodes.append('No')
df['Number of Right Branching Nodes'] = RightBranchingNodes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-80bd4898f75f> in <module>()
# ----> 1 nlp = spacy.load("en_core_web_sm")
#       2 RightBranchingNodes = []
#       3 for sentence in df['After Preprocessing']:
#       4   doc = nlp(sentence)
#       5   try:
#
# NameError: name 'spacy' is not defined

# %% [markdown]
# **Sentence Length**

# %%
df['Sentenece Length'] = df['Full Review'].apply(lambda x: len(x))
df
